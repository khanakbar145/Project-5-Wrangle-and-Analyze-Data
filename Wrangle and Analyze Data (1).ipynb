# %% [markdown]
# # Wrangle and Analyze Data Project
#  ## By Khan Akbar

# %% [markdown]
# # Introduction

# %% [markdown]
# The purpose of this project is to put in practice what I learned in data wrangling data section from Udacity Data Analysis Nanodegree program. The dataset that is wrangled is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs.

# %% [markdown]
# # Gathering data

# %% [markdown]
# 1. **Twitter archive file:** download this file manually by clicking the following link: twitter_archive_enhanced.csv
#
# - **The tweet image predictions**, i.e., what breed of dog (or other object, animal, etc.) is present in each tweet according to a neural network. This file (image_predictions.tsv) is hosted on Udacity's servers and should be downloaded programmatically using the Requests library and the following URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv
#
# - **Twitter API & JSON:** Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file.
#     Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.

# %%
import pandas as pd
import numpy as np
import requests
import tweepy as tweepy
import json
from tweepy.parsers import JSONParser
import time
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %% [markdown]
# ## Gather Data

# %%
# Read in the twitter archive enhanced csv given to us
df_twitter_archive = pd.read_csv('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/twitter-archive-enhanced.csv')
df_twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
# Gather image predictions from Udacity's servers
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# check response code
response
# Out:
# <Response [200]>

# %%
# Save the provided image predictions
with open(url.split('/')[-1], mode='wb') as file:
    file.write(response.content)

# %%
# Read the image predictions tsv file into a dataframe
image_predictions = pd.read_csv('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/image-predictions.tsv', sep='\t')
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
# Access the twitter archives using your unique keys and tokens
consumer_key = 'RKKU0Sw9r5WE4fAwBI9cdpO6o'
consumer_secret = 'PObbO1I2drpHc9hVPoTuIaGNKdOzd0h7FCiQRqQBpdh5K05ad5'
access_token = '836980357870288896-Juk4sW5sIMT7LMyfQt25KMU02rIoQnV'
access_secret = 'skUFLxvlCwS1KxCBgd2bqXsIGTtiv3KLIzEO3a5d02iqw'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, parser=JSONParser(), wait_on_rate_limit=True)

# %%
# Do a test run of the api
tweet = api.get_status(666029285002620928,tweet_mode='extended')

# %%
# Do a test run of the api
tweet = api.get_status(887473957103951883,tweet_mode='extended')

# %%
# Testing
print(tweet['id'])
print(tweet['retweet_count'])
# Out:
# 887473957103951883
# 16453

# %%
# Query the api and get erroneous tweets. Track timing of tweet completion as well.
df_list = []
errors_list = []

tweets = df_twitter_archive['tweet_id']

now = time.time()

for index, t in enumerate(tweets):

    try:
        start = time.time()
        tweet = api.get_status(t,tweet_mode='extended')
        end = time.time()
        print("Reading Tweet {}/{}. ({}%) complete. Elapsed Time = {}".format((index+1),len(tweets), round(((index+1)/len(tweets)) * 100,1), round((end - start),2)))
        retweet_count = tweet['retweet_count']
        favorite_count = tweet['favorite_count']
        df_list.append({'tweet_id':int(t),
                        'retweet_count':int(retweet_count),
                        'favorite_count':int(favorite_count)
                       })

    
    
    except Exception as e:
        print(str(t) + str(e))
        errors_list.append(t)

then = time.time()
diff = round(then - now)
minutes = diff // 60
seconds = diff % 60
print("Reading Process Completed. Elapsed Time is {}:{}".format(minutes, seconds))
# Out:
# Reading Tweet 1/2356. (0.0%) complete. Elapsed Time = 1.88
# Reading Tweet 2/2356. (0.1%) complete. Elapsed Time = 2.31
# Reading Tweet 3/2356. (0.1%) complete. Elapsed Time = 2.24
# Reading Tweet 4/2356. (0.2%) complete. Elapsed Time = 1.81
# Reading Tweet 5/2356. (0.2%) complete. Elapsed Time = 2.09
# Reading Tweet 6/2356. (0.3%) complete. Elapsed Time = 1.42
# Reading Tweet 7/2356. (0.3%) complete. Elapsed Time = 2.06
# Reading Tweet 8/2356. (0.3%) complete. Elapsed Time = 1.84
# Reading Tweet 9/2356. (0.4%) complete. Elapsed Time = 1.23
# Reading Tweet 10/2356. (0.4%) complete. Elapsed Time = 2.05
# Reading Tweet 11/2356. (0.5%) complete. Elapsed Time = 1.53
# Reading Tweet 12/2356. (0.5%) complete. Elapsed Time = 1.94
# Reading Tweet 13/2356. (0.6%) complete. Elapsed Time = 2.04
# Reading Tweet 14/2356. (0.6%) complete. Elapsed Time = 1.42
# Reading Tweet 15/2356. (0.6%) complete. Elapsed Time = 1.65
# Reading Tweet 16/2356. (0.7%) complete. Elapsed Time = 1.58
# Reading Tweet 17/2356. (0.7%) complete. Elapsed Time = 1.72
# Reading Tweet 18/2356. (0.8%) complete. Elapsed Time = 1.81
# Reading Tweet 19/2356. (0.8%) complete. Elapsed Time = 1.85
# 888202515573088257[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 21/2356. (0.9%) complete. Elapsed Time = 2.67
# Reading Tweet 22/2356. (0.9%) complete. Elapsed Time = 2.46
# Reading Tweet 23/2356. (1.0%) complete. Elapsed Time = 1.94
# Reading Tweet 24/2356. (1.0%) complete. Elapsed Time = 2.15
# Reading Tweet 25/2356. (1.1%) complete. Elapsed Time = 1.85
# Reading Tweet 26/2356. (1.1%) complete. Elapsed Time = 2.05
# Reading Tweet 27/2356. (1.1%) complete. Elapsed Time = 2.38
# Reading Tweet 28/2356. (1.2%) complete. Elapsed Time = 2.34
# Reading Tweet 29/2356. (1.2%) complete. Elapsed Time = 1.63
# Reading Tweet 30/2356. (1.3%) complete. Elapsed Time = 2.26
# Reading Tweet 31/2356. (1.3%) complete. Elapsed Time = 1.42
# Reading Tweet 32/2356. (1.4%) complete. Elapsed Time = 1.93
# Reading Tweet 33/2356. (1.4%) complete. Elapsed Time = 1.76
# Reading Tweet 34/2356. (1.4%) complete. Elapsed Time = 1.85
# Reading Tweet 35/2356. (1.5%) complete. Elapsed Time = 2.17
# Reading Tweet 36/2356. (1.5%) complete. Elapsed Time = 2.33
# Reading Tweet 37/2356. (1.6%) complete. Elapsed Time = 2.12
# Reading Tweet 38/2356. (1.6%) complete. Elapsed Time = 1.78
# Reading Tweet 39/2356. (1.7%) complete. Elapsed Time = 2.14
# Reading Tweet 40/2356. (1.7%) complete. Elapsed Time = 1.95
# Reading Tweet 41/2356. (1.7%) complete. Elapsed Time = 2.26
# Reading Tweet 42/2356. (1.8%) complete. Elapsed Time = 1.59
# Reading Tweet 43/2356. (1.8%) complete. Elapsed Time = 1.63
# Reading Tweet 44/2356. (1.9%) complete. Elapsed Time = 1.3
# Reading Tweet 45/2356. (1.9%) complete. Elapsed Time = 2.22
# Reading Tweet 46/2356. (2.0%) complete. Elapsed Time = 2.03
# Reading Tweet 47/2356. (2.0%) complete. Elapsed Time = 1.44
# Reading Tweet 48/2356. (2.0%) complete. Elapsed Time = 2.25
# Reading Tweet 49/2356. (2.1%) complete. Elapsed Time = 1.84
# Reading Tweet 50/2356. (2.1%) complete. Elapsed Time = 2.05
# Reading Tweet 51/2356. (2.2%) complete. Elapsed Time = 2.05
# Reading Tweet 52/2356. (2.2%) complete. Elapsed Time = 2.06
# Reading Tweet 53/2356. (2.2%) complete. Elapsed Time = 1.6
# Reading Tweet 54/2356. (2.3%) complete. Elapsed Time = 1.87
# Reading Tweet 55/2356. (2.3%) complete. Elapsed Time = 2.05
# Reading Tweet 56/2356. (2.4%) complete. Elapsed Time = 2.39
# Reading Tweet 57/2356. (2.4%) complete. Elapsed Time = 2.11
# Reading Tweet 58/2356. (2.5%) complete. Elapsed Time = 1.74
# Reading Tweet 59/2356. (2.5%) complete. Elapsed Time = 2.39
# Reading Tweet 60/2356. (2.5%) complete. Elapsed Time = 1.81
# Reading Tweet 61/2356. (2.6%) complete. Elapsed Time = 2.04
# Reading Tweet 62/2356. (2.6%) complete. Elapsed Time = 1.53
# Reading Tweet 63/2356. (2.7%) complete. Elapsed Time = 2.34
# Reading Tweet 64/2356. (2.7%) complete. Elapsed Time = 2.32
# Reading Tweet 65/2356. (2.8%) complete. Elapsed Time = 1.39
# Reading Tweet 66/2356. (2.8%) complete. Elapsed Time = 1.23
# Reading Tweet 67/2356. (2.8%) complete. Elapsed Time = 2.05
# Reading Tweet 68/2356. (2.9%) complete. Elapsed Time = 2.45
# Reading Tweet 69/2356. (2.9%) complete. Elapsed Time = 2.25
# Reading Tweet 70/2356. (3.0%) complete. Elapsed Time = 2.05
# Reading Tweet 71/2356. (3.0%) complete. Elapsed Time = 2.26
# Reading Tweet 72/2356. (3.1%) complete. Elapsed Time = 1.64
# Reading Tweet 73/2356. (3.1%) complete. Elapsed Time = 1.43
# Reading Tweet 74/2356. (3.1%) complete. Elapsed Time = 1.64
# Reading Tweet 75/2356. (3.2%) complete. Elapsed Time = 1.24
# Reading Tweet 76/2356. (3.2%) complete. Elapsed Time = 2.05
# Reading Tweet 77/2356. (3.3%) complete. Elapsed Time = 2.25
# Reading Tweet 78/2356. (3.3%) complete. Elapsed Time = 1.84
# Reading Tweet 79/2356. (3.4%) complete. Elapsed Time = 1.84
# Reading Tweet 80/2356. (3.4%) complete. Elapsed Time = 2.25
# Reading Tweet 81/2356. (3.4%) complete. Elapsed Time = 2.25
# Reading Tweet 82/2356. (3.5%) complete. Elapsed Time = 1.64
# Reading Tweet 83/2356. (3.5%) complete. Elapsed Time = 2.26
# Reading Tweet 84/2356. (3.6%) complete. Elapsed Time = 2.25
# Reading Tweet 85/2356. (3.6%) complete. Elapsed Time = 2.2
# Reading Tweet 86/2356. (3.7%) complete. Elapsed Time = 1.8
# Reading Tweet 87/2356. (3.7%) complete. Elapsed Time = 1.95
# Reading Tweet 88/2356. (3.7%) complete. Elapsed Time = 1.64
# Reading Tweet 89/2356. (3.8%) complete. Elapsed Time = 2.37
# Reading Tweet 90/2356. (3.8%) complete. Elapsed Time = 1.84
# Reading Tweet 91/2356. (3.9%) complete. Elapsed Time = 1.32
# Reading Tweet 92/2356. (3.9%) complete. Elapsed Time = 1.61
# Reading Tweet 93/2356. (3.9%) complete. Elapsed Time = 1.74
# Reading Tweet 94/2356. (4.0%) complete. Elapsed Time = 1.73
# Reading Tweet 95/2356. (4.0%) complete. Elapsed Time = 1.81
# 873697596434513921[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 97/2356. (4.1%) complete. Elapsed Time = 1.72
# Reading Tweet 98/2356. (4.2%) complete. Elapsed Time = 2.2
# Reading Tweet 99/2356. (4.2%) complete. Elapsed Time = 2.03
# Reading Tweet 100/2356. (4.2%) complete. Elapsed Time = 1.63
# Reading Tweet 101/2356. (4.3%) complete. Elapsed Time = 1.87
# 872668790621863937[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 103/2356. (4.4%) complete. Elapsed Time = 1.44
# Reading Tweet 104/2356. (4.4%) complete. Elapsed Time = 2.01
# 872261713294495745[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 106/2356. (4.5%) complete. Elapsed Time = 2.45
# Reading Tweet 107/2356. (4.5%) complete. Elapsed Time = 2.26
# Reading Tweet 108/2356. (4.6%) complete. Elapsed Time = 2.46
# Reading Tweet 109/2356. (4.6%) complete. Elapsed Time = 2.25
# Reading Tweet 110/2356. (4.7%) complete. Elapsed Time = 2.05
# Reading Tweet 111/2356. (4.7%) complete. Elapsed Time = 1.83
# Reading Tweet 112/2356. (4.8%) complete. Elapsed Time = 1.82
# Reading Tweet 113/2356. (4.8%) complete. Elapsed Time = 2.08
# Reading Tweet 114/2356. (4.8%) complete. Elapsed Time = 2.07
# Reading Tweet 115/2356. (4.9%) complete. Elapsed Time = 2.01
# Reading Tweet 116/2356. (4.9%) complete. Elapsed Time = 1.6
# Reading Tweet 117/2356. (5.0%) complete. Elapsed Time = 2.36
# Reading Tweet 118/2356. (5.0%) complete. Elapsed Time = 1.79
# 869988702071779329[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 120/2356. (5.1%) complete. Elapsed Time = 1.83
# Reading Tweet 121/2356. (5.1%) complete. Elapsed Time = 2.27
# Reading Tweet 122/2356. (5.2%) complete. Elapsed Time = 1.71
# Reading Tweet 123/2356. (5.2%) complete. Elapsed Time = 2.69
# Reading Tweet 124/2356. (5.3%) complete. Elapsed Time = 2.14
# Reading Tweet 125/2356. (5.3%) complete. Elapsed Time = 2.05
# Reading Tweet 126/2356. (5.3%) complete. Elapsed Time = 1.63
# Reading Tweet 127/2356. (5.4%) complete. Elapsed Time = 1.84
# Reading Tweet 128/2356. (5.4%) complete. Elapsed Time = 2.06
# Reading Tweet 129/2356. (5.5%) complete. Elapsed Time = 2.46
# Reading Tweet 130/2356. (5.5%) complete. Elapsed Time = 2.24
# Reading Tweet 131/2356. (5.6%) complete. Elapsed Time = 2.05
# Reading Tweet 132/2356. (5.6%) complete. Elapsed Time = 1.85
# 866816280283807744[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 134/2356. (5.7%) complete. Elapsed Time = 2.26
# Reading Tweet 135/2356. (5.7%) complete. Elapsed Time = 1.59
# Reading Tweet 136/2356. (5.8%) complete. Elapsed Time = 1.9
# Reading Tweet 137/2356. (5.8%) complete. Elapsed Time = 2.24
# Reading Tweet 138/2356. (5.9%) complete. Elapsed Time = 1.59
# Reading Tweet 139/2356. (5.9%) complete. Elapsed Time = 1.9
# Reading Tweet 140/2356. (5.9%) complete. Elapsed Time = 2.25
# Reading Tweet 141/2356. (6.0%) complete. Elapsed Time = 2.6
# Reading Tweet 142/2356. (6.0%) complete. Elapsed Time = 2.4
# Reading Tweet 143/2356. (6.1%) complete. Elapsed Time = 1.71
# Reading Tweet 144/2356. (6.1%) complete. Elapsed Time = 1.66
# Reading Tweet 145/2356. (6.2%) complete. Elapsed Time = 2.47
# Reading Tweet 146/2356. (6.2%) complete. Elapsed Time = 1.63
# Reading Tweet 147/2356. (6.2%) complete. Elapsed Time = 2.57
# Reading Tweet 148/2356. (6.3%) complete. Elapsed Time = 1.53
# Reading Tweet 149/2356. (6.3%) complete. Elapsed Time = 2.25
# Reading Tweet 150/2356. (6.4%) complete. Elapsed Time = 1.86
# Reading Tweet 151/2356. (6.4%) complete. Elapsed Time = 2.04
# Reading Tweet 152/2356. (6.5%) complete. Elapsed Time = 2.25
# Reading Tweet 153/2356. (6.5%) complete. Elapsed Time = 1.85
# Reading Tweet 154/2356. (6.5%) complete. Elapsed Time = 2.05
# Reading Tweet 155/2356. (6.6%) complete. Elapsed Time = 1.64
# 861769973181624320[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 157/2356. (6.7%) complete. Elapsed Time = 1.85
# Reading Tweet 158/2356. (6.7%) complete. Elapsed Time = 2.05
# Reading Tweet 159/2356. (6.7%) complete. Elapsed Time = 1.55
# Reading Tweet 160/2356. (6.8%) complete. Elapsed Time = 1.73
# Reading Tweet 161/2356. (6.8%) complete. Elapsed Time = 1.52
# Reading Tweet 162/2356. (6.9%) complete. Elapsed Time = 1.47
# Reading Tweet 163/2356. (6.9%) complete. Elapsed Time = 1.53
# Reading Tweet 164/2356. (7.0%) complete. Elapsed Time = 1.65
# Reading Tweet 165/2356. (7.0%) complete. Elapsed Time = 2.04
# Reading Tweet 166/2356. (7.0%) complete. Elapsed Time = 2.43
# Reading Tweet 167/2356. (7.1%) complete. Elapsed Time = 2.07
# Reading Tweet 168/2356. (7.1%) complete. Elapsed Time = 2.46
# Reading Tweet 169/2356. (7.2%) complete. Elapsed Time = 2.01
# Reading Tweet 170/2356. (7.2%) complete. Elapsed Time = 2.5
# Reading Tweet 171/2356. (7.3%) complete. Elapsed Time = 2.25
# Reading Tweet 172/2356. (7.3%) complete. Elapsed Time = 2.26
# Reading Tweet 173/2356. (7.3%) complete. Elapsed Time = 2.25
# Reading Tweet 174/2356. (7.4%) complete. Elapsed Time = 2.25
# Reading Tweet 175/2356. (7.4%) complete. Elapsed Time = 2.25
# Reading Tweet 176/2356. (7.5%) complete. Elapsed Time = 2.58
# Reading Tweet 177/2356. (7.5%) complete. Elapsed Time = 2.13
# Reading Tweet 178/2356. (7.6%) complete. Elapsed Time = 1.64
# Reading Tweet 179/2356. (7.6%) complete. Elapsed Time = 1.91
# Reading Tweet 180/2356. (7.6%) complete. Elapsed Time = 1.84
# Reading Tweet 181/2356. (7.7%) complete. Elapsed Time = 1.98
# Reading Tweet 182/2356. (7.7%) complete. Elapsed Time = 2.03
# 856602993587888130[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 184/2356. (7.8%) complete. Elapsed Time = 1.68
# Reading Tweet 185/2356. (7.9%) complete. Elapsed Time = 1.59
# Reading Tweet 186/2356. (7.9%) complete. Elapsed Time = 1.89
# Reading Tweet 187/2356. (7.9%) complete. Elapsed Time = 2.26
# Reading Tweet 188/2356. (8.0%) complete. Elapsed Time = 2.04
# Reading Tweet 189/2356. (8.0%) complete. Elapsed Time = 1.72
# Reading Tweet 190/2356. (8.1%) complete. Elapsed Time = 1.76
# Reading Tweet 191/2356. (8.1%) complete. Elapsed Time = 1.85
# Reading Tweet 192/2356. (8.1%) complete. Elapsed Time = 2.12
# Reading Tweet 193/2356. (8.2%) complete. Elapsed Time = 2.02
# Reading Tweet 194/2356. (8.2%) complete. Elapsed Time = 2.62
# Reading Tweet 195/2356. (8.3%) complete. Elapsed Time = 1.57
# Reading Tweet 196/2356. (8.3%) complete. Elapsed Time = 1.91
# Reading Tweet 197/2356. (8.4%) complete. Elapsed Time = 2.04
# Reading Tweet 198/2356. (8.4%) complete. Elapsed Time = 2.45
# Reading Tweet 199/2356. (8.4%) complete. Elapsed Time = 2.06
# Reading Tweet 200/2356. (8.5%) complete. Elapsed Time = 3.48
# Reading Tweet 201/2356. (8.5%) complete. Elapsed Time = 2.34
# Reading Tweet 202/2356. (8.6%) complete. Elapsed Time = 1.35
# Reading Tweet 203/2356. (8.6%) complete. Elapsed Time = 2.05
# Reading Tweet 204/2356. (8.7%) complete. Elapsed Time = 1.84
# Reading Tweet 205/2356. (8.7%) complete. Elapsed Time = 1.63
# Reading Tweet 206/2356. (8.7%) complete. Elapsed Time = 2.26
# Reading Tweet 207/2356. (8.8%) complete. Elapsed Time = 2.15
# Reading Tweet 208/2356. (8.8%) complete. Elapsed Time = 3.4
# Reading Tweet 209/2356. (8.9%) complete. Elapsed Time = 1.82
# Reading Tweet 210/2356. (8.9%) complete. Elapsed Time = 2.77
# Reading Tweet 211/2356. (9.0%) complete. Elapsed Time = 1.73
# 851953902622658560[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 213/2356. (9.0%) complete. Elapsed Time = 2.87
# Reading Tweet 214/2356. (9.1%) complete. Elapsed Time = 3.06
# Reading Tweet 215/2356. (9.1%) complete. Elapsed Time = 1.85
# Reading Tweet 216/2356. (9.2%) complete. Elapsed Time = 2.25
# Reading Tweet 217/2356. (9.2%) complete. Elapsed Time = 1.63
# Reading Tweet 218/2356. (9.3%) complete. Elapsed Time = 2.27
# Reading Tweet 219/2356. (9.3%) complete. Elapsed Time = 1.63
# Reading Tweet 220/2356. (9.3%) complete. Elapsed Time = 1.84
# Reading Tweet 221/2356. (9.4%) complete. Elapsed Time = 2.18
# Reading Tweet 222/2356. (9.4%) complete. Elapsed Time = 2.13
# Reading Tweet 223/2356. (9.5%) complete. Elapsed Time = 1.85
# Reading Tweet 224/2356. (9.5%) complete. Elapsed Time = 2.24
# Reading Tweet 225/2356. (9.6%) complete. Elapsed Time = 1.75
# Reading Tweet 226/2356. (9.6%) complete. Elapsed Time = 1.33
# Reading Tweet 227/2356. (9.6%) complete. Elapsed Time = 2.02
# Reading Tweet 228/2356. (9.7%) complete. Elapsed Time = 1.88
# Reading Tweet 229/2356. (9.7%) complete. Elapsed Time = 2.51
# Reading Tweet 230/2356. (9.8%) complete. Elapsed Time = 2.4
# Reading Tweet 231/2356. (9.8%) complete. Elapsed Time = 1.84
# Reading Tweet 232/2356. (9.8%) complete. Elapsed Time = 1.85
# Reading Tweet 233/2356. (9.9%) complete. Elapsed Time = 2.05
# Reading Tweet 234/2356. (9.9%) complete. Elapsed Time = 1.63
# Reading Tweet 235/2356. (10.0%) complete. Elapsed Time = 2.1
# Reading Tweet 236/2356. (10.0%) complete. Elapsed Time = 2.12
# Reading Tweet 237/2356. (10.1%) complete. Elapsed Time = 1.65
# Reading Tweet 238/2356. (10.1%) complete. Elapsed Time = 2.33
# Reading Tweet 239/2356. (10.1%) complete. Elapsed Time = 2.26
# Reading Tweet 240/2356. (10.2%) complete. Elapsed Time = 1.84
# Reading Tweet 241/2356. (10.2%) complete. Elapsed Time = 2.05
# Reading Tweet 242/2356. (10.3%) complete. Elapsed Time = 1.85
# Reading Tweet 243/2356. (10.3%) complete. Elapsed Time = 1.56
# Reading Tweet 244/2356. (10.4%) complete. Elapsed Time = 2.33
# Reading Tweet 245/2356. (10.4%) complete. Elapsed Time = 2.1
# Reading Tweet 246/2356. (10.4%) complete. Elapsed Time = 1.38
# Reading Tweet 247/2356. (10.5%) complete. Elapsed Time = 1.23
# 845459076796616705[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 249/2356. (10.6%) complete. Elapsed Time = 1.7
# Reading Tweet 250/2356. (10.6%) complete. Elapsed Time = 2.05
# Reading Tweet 251/2356. (10.7%) complete. Elapsed Time = 1.83
# Reading Tweet 252/2356. (10.7%) complete. Elapsed Time = 2.08
# Reading Tweet 253/2356. (10.7%) complete. Elapsed Time = 1.81
# 844704788403113984[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 255/2356. (10.8%) complete. Elapsed Time = 1.77
# Reading Tweet 256/2356. (10.9%) complete. Elapsed Time = 1.41
# Reading Tweet 257/2356. (10.9%) complete. Elapsed Time = 1.94
# Reading Tweet 258/2356. (11.0%) complete. Elapsed Time = 2.25
# Reading Tweet 259/2356. (11.0%) complete. Elapsed Time = 2.25
# Reading Tweet 260/2356. (11.0%) complete. Elapsed Time = 2.26
# 842892208864923648[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 262/2356. (11.1%) complete. Elapsed Time = 1.84
# Reading Tweet 263/2356. (11.2%) complete. Elapsed Time = 2.24
# Reading Tweet 264/2356. (11.2%) complete. Elapsed Time = 2.27
# Reading Tweet 265/2356. (11.2%) complete. Elapsed Time = 2.45
# Reading Tweet 266/2356. (11.3%) complete. Elapsed Time = 2.29
# Reading Tweet 267/2356. (11.3%) complete. Elapsed Time = 1.57
# Reading Tweet 268/2356. (11.4%) complete. Elapsed Time = 1.61
# Reading Tweet 269/2356. (11.4%) complete. Elapsed Time = 1.69
# Reading Tweet 270/2356. (11.5%) complete. Elapsed Time = 1.64
# Reading Tweet 271/2356. (11.5%) complete. Elapsed Time = 1.85
# Reading Tweet 272/2356. (11.5%) complete. Elapsed Time = 2.46
# Reading Tweet 273/2356. (11.6%) complete. Elapsed Time = 2.25
# Reading Tweet 274/2356. (11.6%) complete. Elapsed Time = 2.66
# Reading Tweet 275/2356. (11.7%) complete. Elapsed Time = 2.87
# Reading Tweet 276/2356. (11.7%) complete. Elapsed Time = 1.52
# Reading Tweet 277/2356. (11.8%) complete. Elapsed Time = 2.16
# Reading Tweet 278/2356. (11.8%) complete. Elapsed Time = 2.1
# Reading Tweet 279/2356. (11.8%) complete. Elapsed Time = 1.83
# Reading Tweet 280/2356. (11.9%) complete. Elapsed Time = 2.01
# Reading Tweet 281/2356. (11.9%) complete. Elapsed Time = 1.54
# Reading Tweet 282/2356. (12.0%) complete. Elapsed Time = 1.52
# Reading Tweet 283/2356. (12.0%) complete. Elapsed Time = 2.25
# Reading Tweet 284/2356. (12.1%) complete. Elapsed Time = 1.23
# Reading Tweet 285/2356. (12.1%) complete. Elapsed Time = 1.43
# Reading Tweet 286/2356. (12.1%) complete. Elapsed Time = 1.9
# Reading Tweet 287/2356. (12.2%) complete. Elapsed Time = 1.82
# Reading Tweet 288/2356. (12.2%) complete. Elapsed Time = 1.77
# Reading Tweet 289/2356. (12.3%) complete. Elapsed Time = 2.49
# Reading Tweet 290/2356. (12.3%) complete. Elapsed Time = 2.07
# Reading Tweet 291/2356. (12.4%) complete. Elapsed Time = 1.48
# Reading Tweet 292/2356. (12.4%) complete. Elapsed Time = 1.9
# Reading Tweet 293/2356. (12.4%) complete. Elapsed Time = 1.63
# Reading Tweet 294/2356. (12.5%) complete. Elapsed Time = 1.5
# Reading Tweet 295/2356. (12.5%) complete. Elapsed Time = 1.85
# Reading Tweet 296/2356. (12.6%) complete. Elapsed Time = 1.59
# 837366284874571778[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 298/2356. (12.6%) complete. Elapsed Time = 1.57
# 837012587749474308[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 300/2356. (12.7%) complete. Elapsed Time = 2.18
# Reading Tweet 301/2356. (12.8%) complete. Elapsed Time = 1.94
# Reading Tweet 302/2356. (12.8%) complete. Elapsed Time = 2.12
# Reading Tweet 303/2356. (12.9%) complete. Elapsed Time = 1.98
# Reading Tweet 304/2356. (12.9%) complete. Elapsed Time = 1.66
# Reading Tweet 305/2356. (12.9%) complete. Elapsed Time = 1.97
# Reading Tweet 306/2356. (13.0%) complete. Elapsed Time = 1.69
# Reading Tweet 307/2356. (13.0%) complete. Elapsed Time = 2.04
# Reading Tweet 308/2356. (13.1%) complete. Elapsed Time = 2.67
# Reading Tweet 309/2356. (13.1%) complete. Elapsed Time = 2.66
# Reading Tweet 310/2356. (13.2%) complete. Elapsed Time = 2.52
# Reading Tweet 311/2356. (13.2%) complete. Elapsed Time = 3.17
# Reading Tweet 312/2356. (13.2%) complete. Elapsed Time = 2.5
# Reading Tweet 313/2356. (13.3%) complete. Elapsed Time = 1.64
# Reading Tweet 314/2356. (13.3%) complete. Elapsed Time = 2.24
# Reading Tweet 315/2356. (13.4%) complete. Elapsed Time = 1.83
# Reading Tweet 316/2356. (13.4%) complete. Elapsed Time = 1.84
# Reading Tweet 317/2356. (13.5%) complete. Elapsed Time = 2.3
# Reading Tweet 318/2356. (13.5%) complete. Elapsed Time = 1.62
# Reading Tweet 319/2356. (13.5%) complete. Elapsed Time = 2.08
# Reading Tweet 320/2356. (13.6%) complete. Elapsed Time = 1.59
# Reading Tweet 321/2356. (13.6%) complete. Elapsed Time = 1.65
# Reading Tweet 322/2356. (13.7%) complete. Elapsed Time = 2.04
# Reading Tweet 323/2356. (13.7%) complete. Elapsed Time = 1.84
# Reading Tweet 324/2356. (13.8%) complete. Elapsed Time = 1.85
# Reading Tweet 325/2356. (13.8%) complete. Elapsed Time = 2.05
# Reading Tweet 326/2356. (13.8%) complete. Elapsed Time = 2.07
# Reading Tweet 327/2356. (13.9%) complete. Elapsed Time = 1.82
# Reading Tweet 328/2356. (13.9%) complete. Elapsed Time = 2.05
# Reading Tweet 329/2356. (14.0%) complete. Elapsed Time = 1.63
# Reading Tweet 330/2356. (14.0%) complete. Elapsed Time = 2.2
# Reading Tweet 331/2356. (14.0%) complete. Elapsed Time = 2.51
# Reading Tweet 332/2356. (14.1%) complete. Elapsed Time = 2.26
# Reading Tweet 333/2356. (14.1%) complete. Elapsed Time = 2.04
# Reading Tweet 334/2356. (14.2%) complete. Elapsed Time = 1.64
# Reading Tweet 335/2356. (14.2%) complete. Elapsed Time = 2.24
# Reading Tweet 336/2356. (14.3%) complete. Elapsed Time = 2.26
# Reading Tweet 337/2356. (14.3%) complete. Elapsed Time = 2.05
# Reading Tweet 338/2356. (14.3%) complete. Elapsed Time = 1.84
# Reading Tweet 339/2356. (14.4%) complete. Elapsed Time = 1.84
# Reading Tweet 340/2356. (14.4%) complete. Elapsed Time = 2.05
# Reading Tweet 341/2356. (14.5%) complete. Elapsed Time = 2.77
# Reading Tweet 342/2356. (14.5%) complete. Elapsed Time = 1.93
# Reading Tweet 343/2356. (14.6%) complete. Elapsed Time = 2.26
# Reading Tweet 344/2356. (14.6%) complete. Elapsed Time = 1.86
# Reading Tweet 345/2356. (14.6%) complete. Elapsed Time = 1.62
# Reading Tweet 346/2356. (14.7%) complete. Elapsed Time = 3.27
# Reading Tweet 347/2356. (14.7%) complete. Elapsed Time = 5.93
# Reading Tweet 348/2356. (14.8%) complete. Elapsed Time = 2.87
# Reading Tweet 349/2356. (14.8%) complete. Elapsed Time = 2.46
# Reading Tweet 350/2356. (14.9%) complete. Elapsed Time = 2.05
# Reading Tweet 351/2356. (14.9%) complete. Elapsed Time = 2.09
# Reading Tweet 352/2356. (14.9%) complete. Elapsed Time = 1.6
# Reading Tweet 353/2356. (15.0%) complete. Elapsed Time = 1.99
# Reading Tweet 354/2356. (15.0%) complete. Elapsed Time = 2.37
# Reading Tweet 355/2356. (15.1%) complete. Elapsed Time = 2.2
# Reading Tweet 356/2356. (15.1%) complete. Elapsed Time = 2.61
# Reading Tweet 357/2356. (15.2%) complete. Elapsed Time = 1.75
# Reading Tweet 358/2356. (15.2%) complete. Elapsed Time = 1.98
# Reading Tweet 359/2356. (15.2%) complete. Elapsed Time = 1.44
# Reading Tweet 360/2356. (15.3%) complete. Elapsed Time = 1.84
# Reading Tweet 361/2356. (15.3%) complete. Elapsed Time = 2.29
# Reading Tweet 362/2356. (15.4%) complete. Elapsed Time = 1.6
# Reading Tweet 363/2356. (15.4%) complete. Elapsed Time = 2.26
# 829374341691346946[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 365/2356. (15.5%) complete. Elapsed Time = 1.84
# Reading Tweet 366/2356. (15.5%) complete. Elapsed Time = 1.63
# Reading Tweet 367/2356. (15.6%) complete. Elapsed Time = 2.26
# Reading Tweet 368/2356. (15.6%) complete. Elapsed Time = 2.26
# Reading Tweet 369/2356. (15.7%) complete. Elapsed Time = 2.24
# Reading Tweet 370/2356. (15.7%) complete. Elapsed Time = 1.64
# Reading Tweet 371/2356. (15.7%) complete. Elapsed Time = 1.69
# Reading Tweet 372/2356. (15.8%) complete. Elapsed Time = 4.02
# Reading Tweet 373/2356. (15.8%) complete. Elapsed Time = 2.64
# Reading Tweet 374/2356. (15.9%) complete. Elapsed Time = 1.69
# Reading Tweet 375/2356. (15.9%) complete. Elapsed Time = 2.05
# Reading Tweet 376/2356. (16.0%) complete. Elapsed Time = 1.13
# Reading Tweet 377/2356. (16.0%) complete. Elapsed Time = 1.02
# Reading Tweet 378/2356. (16.0%) complete. Elapsed Time = 0.99
# Reading Tweet 379/2356. (16.1%) complete. Elapsed Time = 1.08
# Reading Tweet 380/2356. (16.1%) complete. Elapsed Time = 1.11
# Reading Tweet 381/2356. (16.2%) complete. Elapsed Time = 1.06
# Reading Tweet 382/2356. (16.2%) complete. Elapsed Time = 1.1
# 827228250799742977[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 384/2356. (16.3%) complete. Elapsed Time = 1.06
# Reading Tweet 385/2356. (16.3%) complete. Elapsed Time = 1.18
# Reading Tweet 386/2356. (16.4%) complete. Elapsed Time = 1.02
# Reading Tweet 387/2356. (16.4%) complete. Elapsed Time = 1.81
# Reading Tweet 388/2356. (16.5%) complete. Elapsed Time = 1.03
# Reading Tweet 389/2356. (16.5%) complete. Elapsed Time = 1.16
# Reading Tweet 390/2356. (16.6%) complete. Elapsed Time = 1.21
# Reading Tweet 391/2356. (16.6%) complete. Elapsed Time = 1.09
# Reading Tweet 392/2356. (16.6%) complete. Elapsed Time = 1.96
# Reading Tweet 393/2356. (16.7%) complete. Elapsed Time = 1.98
# Reading Tweet 394/2356. (16.7%) complete. Elapsed Time = 1.38
# Reading Tweet 395/2356. (16.8%) complete. Elapsed Time = 1.0
# Reading Tweet 396/2356. (16.8%) complete. Elapsed Time = 1.04
# Reading Tweet 397/2356. (16.9%) complete. Elapsed Time = 1.25
# Reading Tweet 398/2356. (16.9%) complete. Elapsed Time = 2.25
# Reading Tweet 399/2356. (16.9%) complete. Elapsed Time = 1.84
# Reading Tweet 400/2356. (17.0%) complete. Elapsed Time = 1.84
# Reading Tweet 401/2356. (17.0%) complete. Elapsed Time = 1.38
# Reading Tweet 402/2356. (17.1%) complete. Elapsed Time = 1.3
# Reading Tweet 403/2356. (17.1%) complete. Elapsed Time = 1.62
# Reading Tweet 404/2356. (17.1%) complete. Elapsed Time = 1.74
# Reading Tweet 405/2356. (17.2%) complete. Elapsed Time = 2.15
# Reading Tweet 406/2356. (17.2%) complete. Elapsed Time = 2.46
# Reading Tweet 407/2356. (17.3%) complete. Elapsed Time = 2.25
# Reading Tweet 408/2356. (17.3%) complete. Elapsed Time = 2.25
# Reading Tweet 409/2356. (17.4%) complete. Elapsed Time = 2.25
# Reading Tweet 410/2356. (17.4%) complete. Elapsed Time = 1.23
# Reading Tweet 411/2356. (17.4%) complete. Elapsed Time = 1.85
# Reading Tweet 412/2356. (17.5%) complete. Elapsed Time = 2.25
# Reading Tweet 413/2356. (17.5%) complete. Elapsed Time = 1.25
# Reading Tweet 414/2356. (17.6%) complete. Elapsed Time = 1.98
# Reading Tweet 415/2356. (17.6%) complete. Elapsed Time = 1.7
# Reading Tweet 416/2356. (17.7%) complete. Elapsed Time = 1.18
# Reading Tweet 417/2356. (17.7%) complete. Elapsed Time = 1.67
# Reading Tweet 418/2356. (17.7%) complete. Elapsed Time = 1.84
# Reading Tweet 419/2356. (17.8%) complete. Elapsed Time = 2.01
# Reading Tweet 420/2356. (17.8%) complete. Elapsed Time = 2.09
# Reading Tweet 421/2356. (17.9%) complete. Elapsed Time = 1.41
# Reading Tweet 422/2356. (17.9%) complete. Elapsed Time = 1.26
# Reading Tweet 423/2356. (18.0%) complete. Elapsed Time = 5.27
# Reading Tweet 424/2356. (18.0%) complete. Elapsed Time = 2.14
# Reading Tweet 425/2356. (18.0%) complete. Elapsed Time = 2.63
# Reading Tweet 426/2356. (18.1%) complete. Elapsed Time = 3.07
# Reading Tweet 427/2356. (18.1%) complete. Elapsed Time = 1.84
# Reading Tweet 428/2356. (18.2%) complete. Elapsed Time = 1.64
# Reading Tweet 429/2356. (18.2%) complete. Elapsed Time = 2.12
# Reading Tweet 430/2356. (18.3%) complete. Elapsed Time = 2.39
# Reading Tweet 431/2356. (18.3%) complete. Elapsed Time = 2.05
# Reading Tweet 432/2356. (18.3%) complete. Elapsed Time = 1.41
# Reading Tweet 433/2356. (18.4%) complete. Elapsed Time = 2.07
# Reading Tweet 434/2356. (18.4%) complete. Elapsed Time = 1.26
# Reading Tweet 435/2356. (18.5%) complete. Elapsed Time = 1.55
# Reading Tweet 436/2356. (18.5%) complete. Elapsed Time = 1.48
# Reading Tweet 437/2356. (18.5%) complete. Elapsed Time = 1.98
# Reading Tweet 438/2356. (18.6%) complete. Elapsed Time = 1.68
# Reading Tweet 439/2356. (18.6%) complete. Elapsed Time = 1.26
# Reading Tweet 440/2356. (18.7%) complete. Elapsed Time = 2.05
# Reading Tweet 441/2356. (18.7%) complete. Elapsed Time = 2.46
# Reading Tweet 442/2356. (18.8%) complete. Elapsed Time = 2.25
# Reading Tweet 443/2356. (18.8%) complete. Elapsed Time = 2.07
# Reading Tweet 444/2356. (18.8%) complete. Elapsed Time = 2.44
# Reading Tweet 445/2356. (18.9%) complete. Elapsed Time = 2.18
# Reading Tweet 446/2356. (18.9%) complete. Elapsed Time = 1.15
# Reading Tweet 447/2356. (19.0%) complete. Elapsed Time = 1.79
# Reading Tweet 448/2356. (19.0%) complete. Elapsed Time = 2.25
# Reading Tweet 449/2356. (19.1%) complete. Elapsed Time = 2.87
# Reading Tweet 450/2356. (19.1%) complete. Elapsed Time = 1.84
# Reading Tweet 451/2356. (19.1%) complete. Elapsed Time = 1.99
# Reading Tweet 452/2356. (19.2%) complete. Elapsed Time = 2.05
# Reading Tweet 453/2356. (19.2%) complete. Elapsed Time = 1.48
# Reading Tweet 454/2356. (19.3%) complete. Elapsed Time = 1.85
# Reading Tweet 455/2356. (19.3%) complete. Elapsed Time = 1.81
# Reading Tweet 456/2356. (19.4%) complete. Elapsed Time = 4.85
# Reading Tweet 457/2356. (19.4%) complete. Elapsed Time = 3.26
# Reading Tweet 458/2356. (19.4%) complete. Elapsed Time = 1.77
# Reading Tweet 459/2356. (19.5%) complete. Elapsed Time = 1.61
# Reading Tweet 460/2356. (19.5%) complete. Elapsed Time = 1.23
# Reading Tweet 461/2356. (19.6%) complete. Elapsed Time = 2.45
# Reading Tweet 462/2356. (19.6%) complete. Elapsed Time = 1.88
# Reading Tweet 463/2356. (19.7%) complete. Elapsed Time = 1.53
# Reading Tweet 464/2356. (19.7%) complete. Elapsed Time = 1.5
# Reading Tweet 465/2356. (19.7%) complete. Elapsed Time = 1.83
# Reading Tweet 466/2356. (19.8%) complete. Elapsed Time = 1.85
# Reading Tweet 467/2356. (19.8%) complete. Elapsed Time = 1.52
# Reading Tweet 468/2356. (19.9%) complete. Elapsed Time = 2.27
# Reading Tweet 469/2356. (19.9%) complete. Elapsed Time = 1.75
# Reading Tweet 470/2356. (19.9%) complete. Elapsed Time = 1.84
# Reading Tweet 471/2356. (20.0%) complete. Elapsed Time = 3.48
# Reading Tweet 472/2356. (20.0%) complete. Elapsed Time = 1.94
# Reading Tweet 473/2356. (20.1%) complete. Elapsed Time = 2.08
# Reading Tweet 474/2356. (20.1%) complete. Elapsed Time = 1.74
# Reading Tweet 475/2356. (20.2%) complete. Elapsed Time = 1.89
# Reading Tweet 476/2356. (20.2%) complete. Elapsed Time = 1.37
# Reading Tweet 477/2356. (20.2%) complete. Elapsed Time = 2.07
# Reading Tweet 478/2356. (20.3%) complete. Elapsed Time = 1.62
# Reading Tweet 479/2356. (20.3%) complete. Elapsed Time = 1.67
# Reading Tweet 480/2356. (20.4%) complete. Elapsed Time = 1.98
# Reading Tweet 481/2356. (20.4%) complete. Elapsed Time = 3.39
# Reading Tweet 482/2356. (20.5%) complete. Elapsed Time = 2.59
# Reading Tweet 483/2356. (20.5%) complete. Elapsed Time = 1.59
# Reading Tweet 484/2356. (20.5%) complete. Elapsed Time = 1.68
# Reading Tweet 485/2356. (20.6%) complete. Elapsed Time = 2.45
# Reading Tweet 486/2356. (20.6%) complete. Elapsed Time = 1.65
# Reading Tweet 487/2356. (20.7%) complete. Elapsed Time = 1.85
# Reading Tweet 488/2356. (20.7%) complete. Elapsed Time = 2.25
# Reading Tweet 489/2356. (20.8%) complete. Elapsed Time = 3.08
# Reading Tweet 490/2356. (20.8%) complete. Elapsed Time = 1.89
# Reading Tweet 491/2356. (20.8%) complete. Elapsed Time = 2.0
# Reading Tweet 492/2356. (20.9%) complete. Elapsed Time = 1.64
# Reading Tweet 493/2356. (20.9%) complete. Elapsed Time = 2.66
# Reading Tweet 494/2356. (21.0%) complete. Elapsed Time = 3.42
# Reading Tweet 495/2356. (21.0%) complete. Elapsed Time = 1.5
# Reading Tweet 496/2356. (21.1%) complete. Elapsed Time = 2.25
# Reading Tweet 497/2356. (21.1%) complete. Elapsed Time = 1.84
# Reading Tweet 498/2356. (21.1%) complete. Elapsed Time = 1.4
# Reading Tweet 499/2356. (21.2%) complete. Elapsed Time = 1.85
# Reading Tweet 500/2356. (21.2%) complete. Elapsed Time = 1.66
# Reading Tweet 501/2356. (21.3%) complete. Elapsed Time = 1.72
# Reading Tweet 502/2356. (21.3%) complete. Elapsed Time = 1.78
# Reading Tweet 503/2356. (21.3%) complete. Elapsed Time = 1.64
# Reading Tweet 504/2356. (21.4%) complete. Elapsed Time = 1.84
# Reading Tweet 505/2356. (21.4%) complete. Elapsed Time = 1.63
# Reading Tweet 506/2356. (21.5%) complete. Elapsed Time = 2.46
# 812747805718642688[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 508/2356. (21.6%) complete. Elapsed Time = 2.65
# Reading Tweet 509/2356. (21.6%) complete. Elapsed Time = 2.06
# Reading Tweet 510/2356. (21.6%) complete. Elapsed Time = 4.41
# Reading Tweet 511/2356. (21.7%) complete. Elapsed Time = 2.66
# Reading Tweet 512/2356. (21.7%) complete. Elapsed Time = 2.34
# Reading Tweet 513/2356. (21.8%) complete. Elapsed Time = 2.66
# Reading Tweet 514/2356. (21.8%) complete. Elapsed Time = 1.43
# Reading Tweet 515/2356. (21.9%) complete. Elapsed Time = 1.64
# Reading Tweet 516/2356. (21.9%) complete. Elapsed Time = 1.43
# Reading Tweet 517/2356. (21.9%) complete. Elapsed Time = 2.05
# Reading Tweet 518/2356. (22.0%) complete. Elapsed Time = 2.25
# Reading Tweet 519/2356. (22.0%) complete. Elapsed Time = 1.84
# Reading Tweet 520/2356. (22.1%) complete. Elapsed Time = 2.04
# Reading Tweet 521/2356. (22.1%) complete. Elapsed Time = 1.84
# Reading Tweet 522/2356. (22.2%) complete. Elapsed Time = 1.65
# Reading Tweet 523/2356. (22.2%) complete. Elapsed Time = 1.79
# Reading Tweet 524/2356. (22.2%) complete. Elapsed Time = 1.58
# Reading Tweet 525/2356. (22.3%) complete. Elapsed Time = 1.74
# Reading Tweet 526/2356. (22.3%) complete. Elapsed Time = 1.79
# Reading Tweet 527/2356. (22.4%) complete. Elapsed Time = 1.26
# Reading Tweet 528/2356. (22.4%) complete. Elapsed Time = 2.07
# Reading Tweet 529/2356. (22.5%) complete. Elapsed Time = 2.05
# Reading Tweet 530/2356. (22.5%) complete. Elapsed Time = 1.64
# Reading Tweet 531/2356. (22.5%) complete. Elapsed Time = 1.64
# Reading Tweet 532/2356. (22.6%) complete. Elapsed Time = 2.05
# Reading Tweet 533/2356. (22.6%) complete. Elapsed Time = 1.84
# Reading Tweet 534/2356. (22.7%) complete. Elapsed Time = 2.05
# Reading Tweet 535/2356. (22.7%) complete. Elapsed Time = 2.46
# Reading Tweet 536/2356. (22.8%) complete. Elapsed Time = 1.69
# Reading Tweet 537/2356. (22.8%) complete. Elapsed Time = 1.8
# Reading Tweet 538/2356. (22.8%) complete. Elapsed Time = 2.26
# Reading Tweet 539/2356. (22.9%) complete. Elapsed Time = 1.64
# Reading Tweet 540/2356. (22.9%) complete. Elapsed Time = 1.63
# Reading Tweet 541/2356. (23.0%) complete. Elapsed Time = 1.39
# Reading Tweet 542/2356. (23.0%) complete. Elapsed Time = 1.56
# Reading Tweet 543/2356. (23.0%) complete. Elapsed Time = 1.67
# Reading Tweet 544/2356. (23.1%) complete. Elapsed Time = 1.2
# Reading Tweet 545/2356. (23.1%) complete. Elapsed Time = 1.33
# Reading Tweet 546/2356. (23.2%) complete. Elapsed Time = 1.07
# Reading Tweet 547/2356. (23.2%) complete. Elapsed Time = 1.43
# Reading Tweet 548/2356. (23.3%) complete. Elapsed Time = 0.97
# Reading Tweet 549/2356. (23.3%) complete. Elapsed Time = 1.03
# Reading Tweet 550/2356. (23.3%) complete. Elapsed Time = 1.18
# Reading Tweet 551/2356. (23.4%) complete. Elapsed Time = 1.44
# Reading Tweet 552/2356. (23.4%) complete. Elapsed Time = 1.49
# Reading Tweet 553/2356. (23.5%) complete. Elapsed Time = 2.14
# Reading Tweet 554/2356. (23.5%) complete. Elapsed Time = 1.48
# Reading Tweet 555/2356. (23.6%) complete. Elapsed Time = 2.2
# Reading Tweet 556/2356. (23.6%) complete. Elapsed Time = 1.74
# Reading Tweet 557/2356. (23.6%) complete. Elapsed Time = 1.79
# Reading Tweet 558/2356. (23.7%) complete. Elapsed Time = 2.12
# Reading Tweet 559/2356. (23.7%) complete. Elapsed Time = 1.72
# Reading Tweet 560/2356. (23.8%) complete. Elapsed Time = 1.7
# Reading Tweet 561/2356. (23.8%) complete. Elapsed Time = 1.69
# Reading Tweet 562/2356. (23.9%) complete. Elapsed Time = 2.46
# Reading Tweet 563/2356. (23.9%) complete. Elapsed Time = 2.05
# Reading Tweet 564/2356. (23.9%) complete. Elapsed Time = 1.8
# Reading Tweet 565/2356. (24.0%) complete. Elapsed Time = 2.28
# Reading Tweet 566/2356. (24.0%) complete. Elapsed Time = 2.26
# 802247111496568832[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 568/2356. (24.1%) complete. Elapsed Time = 1.86
# Reading Tweet 569/2356. (24.2%) complete. Elapsed Time = 1.41
# Reading Tweet 570/2356. (24.2%) complete. Elapsed Time = 1.03
# Reading Tweet 571/2356. (24.2%) complete. Elapsed Time = 0.99
# Reading Tweet 572/2356. (24.3%) complete. Elapsed Time = 1.2
# Reading Tweet 573/2356. (24.3%) complete. Elapsed Time = 1.11
# Reading Tweet 574/2356. (24.4%) complete. Elapsed Time = 1.05
# Reading Tweet 575/2356. (24.4%) complete. Elapsed Time = 1.18
# Reading Tweet 576/2356. (24.4%) complete. Elapsed Time = 1.44
# Reading Tweet 577/2356. (24.5%) complete. Elapsed Time = 1.49
# Reading Tweet 578/2356. (24.5%) complete. Elapsed Time = 1.37
# Reading Tweet 579/2356. (24.6%) complete. Elapsed Time = 2.46
# Reading Tweet 580/2356. (24.6%) complete. Elapsed Time = 1.73
# Reading Tweet 581/2356. (24.7%) complete. Elapsed Time = 1.43
# Reading Tweet 582/2356. (24.7%) complete. Elapsed Time = 1.96
# Reading Tweet 583/2356. (24.7%) complete. Elapsed Time = 2.54
# Reading Tweet 584/2356. (24.8%) complete. Elapsed Time = 2.17
# Reading Tweet 585/2356. (24.8%) complete. Elapsed Time = 2.05
# Reading Tweet 586/2356. (24.9%) complete. Elapsed Time = 1.62
# Reading Tweet 587/2356. (24.9%) complete. Elapsed Time = 2.47
# Reading Tweet 588/2356. (25.0%) complete. Elapsed Time = 2.25
# Reading Tweet 589/2356. (25.0%) complete. Elapsed Time = 1.59
# Reading Tweet 590/2356. (25.0%) complete. Elapsed Time = 1.04
# Reading Tweet 591/2356. (25.1%) complete. Elapsed Time = 1.07
# Reading Tweet 592/2356. (25.1%) complete. Elapsed Time = 1.41
# Reading Tweet 593/2356. (25.2%) complete. Elapsed Time = 2.66
# Reading Tweet 594/2356. (25.2%) complete. Elapsed Time = 2.47
# Reading Tweet 595/2356. (25.3%) complete. Elapsed Time = 2.24
# Reading Tweet 596/2356. (25.3%) complete. Elapsed Time = 2.87
# Reading Tweet 597/2356. (25.3%) complete. Elapsed Time = 2.15
# Reading Tweet 598/2356. (25.4%) complete. Elapsed Time = 2.2
# Reading Tweet 599/2356. (25.4%) complete. Elapsed Time = 2.62
# Reading Tweet 600/2356. (25.5%) complete. Elapsed Time = 1.42
# Reading Tweet 601/2356. (25.5%) complete. Elapsed Time = 1.65
# Reading Tweet 602/2356. (25.6%) complete. Elapsed Time = 1.03
# Reading Tweet 603/2356. (25.6%) complete. Elapsed Time = 1.28
# Reading Tweet 604/2356. (25.6%) complete. Elapsed Time = 1.4
# Reading Tweet 605/2356. (25.7%) complete. Elapsed Time = 1.6
# Reading Tweet 606/2356. (25.7%) complete. Elapsed Time = 1.16
# Reading Tweet 607/2356. (25.8%) complete. Elapsed Time = 1.2
# Reading Tweet 608/2356. (25.8%) complete. Elapsed Time = 2.35
# Reading Tweet 609/2356. (25.8%) complete. Elapsed Time = 1.51
# Reading Tweet 610/2356. (25.9%) complete. Elapsed Time = 1.2
# Reading Tweet 611/2356. (25.9%) complete. Elapsed Time = 1.62
# Reading Tweet 612/2356. (26.0%) complete. Elapsed Time = 2.23
# Reading Tweet 613/2356. (26.0%) complete. Elapsed Time = 2.24
# Reading Tweet 614/2356. (26.1%) complete. Elapsed Time = 2.45
# Reading Tweet 615/2356. (26.1%) complete. Elapsed Time = 1.61
# Reading Tweet 616/2356. (26.1%) complete. Elapsed Time = 1.66
# Reading Tweet 617/2356. (26.2%) complete. Elapsed Time = 1.73
# Reading Tweet 618/2356. (26.2%) complete. Elapsed Time = 1.36
# Reading Tweet 619/2356. (26.3%) complete. Elapsed Time = 2.04
# Reading Tweet 620/2356. (26.3%) complete. Elapsed Time = 1.85
# Reading Tweet 621/2356. (26.4%) complete. Elapsed Time = 1.76
# Reading Tweet 622/2356. (26.4%) complete. Elapsed Time = 1.72
# Reading Tweet 623/2356. (26.4%) complete. Elapsed Time = 1.64
# Reading Tweet 624/2356. (26.5%) complete. Elapsed Time = 1.55
# Reading Tweet 625/2356. (26.5%) complete. Elapsed Time = 1.31
# Reading Tweet 626/2356. (26.6%) complete. Elapsed Time = 1.52
# Reading Tweet 627/2356. (26.6%) complete. Elapsed Time = 0.99
# Reading Tweet 628/2356. (26.7%) complete. Elapsed Time = 1.36
# Reading Tweet 629/2356. (26.7%) complete. Elapsed Time = 1.19
# Reading Tweet 630/2356. (26.7%) complete. Elapsed Time = 1.2
# Reading Tweet 631/2356. (26.8%) complete. Elapsed Time = 1.41
# Reading Tweet 632/2356. (26.8%) complete. Elapsed Time = 1.56
# Reading Tweet 633/2356. (26.9%) complete. Elapsed Time = 2.04
# Reading Tweet 634/2356. (26.9%) complete. Elapsed Time = 1.85
# Reading Tweet 635/2356. (27.0%) complete. Elapsed Time = 2.04
# Reading Tweet 636/2356. (27.0%) complete. Elapsed Time = 1.83
# Reading Tweet 637/2356. (27.0%) complete. Elapsed Time = 2.26
# Reading Tweet 638/2356. (27.1%) complete. Elapsed Time = 2.05
# Reading Tweet 639/2356. (27.1%) complete. Elapsed Time = 1.84
# Reading Tweet 640/2356. (27.2%) complete. Elapsed Time = 1.84
# Reading Tweet 641/2356. (27.2%) complete. Elapsed Time = 2.25
# Reading Tweet 642/2356. (27.2%) complete. Elapsed Time = 1.84
# Reading Tweet 643/2356. (27.3%) complete. Elapsed Time = 2.46
# Reading Tweet 644/2356. (27.3%) complete. Elapsed Time = 1.43
# Reading Tweet 645/2356. (27.4%) complete. Elapsed Time = 1.64
# Reading Tweet 646/2356. (27.4%) complete. Elapsed Time = 1.64
# Reading Tweet 647/2356. (27.5%) complete. Elapsed Time = 1.85
# Reading Tweet 648/2356. (27.5%) complete. Elapsed Time = 2.77
# Reading Tweet 649/2356. (27.5%) complete. Elapsed Time = 1.84
# Reading Tweet 650/2356. (27.6%) complete. Elapsed Time = 1.63
# Reading Tweet 651/2356. (27.6%) complete. Elapsed Time = 1.75
# Reading Tweet 652/2356. (27.7%) complete. Elapsed Time = 1.53
# Reading Tweet 653/2356. (27.7%) complete. Elapsed Time = 2.68
# Reading Tweet 654/2356. (27.8%) complete. Elapsed Time = 1.22
# Reading Tweet 655/2356. (27.8%) complete. Elapsed Time = 1.73
# Reading Tweet 656/2356. (27.8%) complete. Elapsed Time = 1.84
# Reading Tweet 657/2356. (27.9%) complete. Elapsed Time = 2.13
# Reading Tweet 658/2356. (27.9%) complete. Elapsed Time = 1.97
# Reading Tweet 659/2356. (28.0%) complete. Elapsed Time = 1.43
# Reading Tweet 660/2356. (28.0%) complete. Elapsed Time = 1.42
# Reading Tweet 661/2356. (28.1%) complete. Elapsed Time = 2.26
# Reading Tweet 662/2356. (28.1%) complete. Elapsed Time = 1.84
# Reading Tweet 663/2356. (28.1%) complete. Elapsed Time = 1.32
# Reading Tweet 664/2356. (28.2%) complete. Elapsed Time = 2.86
# Reading Tweet 665/2356. (28.2%) complete. Elapsed Time = 2.24
# Reading Tweet 666/2356. (28.3%) complete. Elapsed Time = 1.04
# Reading Tweet 667/2356. (28.3%) complete. Elapsed Time = 1.82
# Reading Tweet 668/2356. (28.4%) complete. Elapsed Time = 2.57
# Reading Tweet 669/2356. (28.4%) complete. Elapsed Time = 3.23
# Reading Tweet 670/2356. (28.4%) complete. Elapsed Time = 1.35
# Reading Tweet 671/2356. (28.5%) complete. Elapsed Time = 1.58
# Reading Tweet 672/2356. (28.5%) complete. Elapsed Time = 2.21
# Reading Tweet 673/2356. (28.6%) complete. Elapsed Time = 2.92
# Reading Tweet 674/2356. (28.6%) complete. Elapsed Time = 1.23
# Reading Tweet 675/2356. (28.7%) complete. Elapsed Time = 2.05
# Reading Tweet 676/2356. (28.7%) complete. Elapsed Time = 1.82
# Reading Tweet 677/2356. (28.7%) complete. Elapsed Time = 1.65
# Reading Tweet 678/2356. (28.8%) complete. Elapsed Time = 1.51
# Reading Tweet 679/2356. (28.8%) complete. Elapsed Time = 1.68
# Reading Tweet 680/2356. (28.9%) complete. Elapsed Time = 1.53
# Reading Tweet 681/2356. (28.9%) complete. Elapsed Time = 2.04
# Reading Tweet 682/2356. (28.9%) complete. Elapsed Time = 2.46
# Reading Tweet 683/2356. (29.0%) complete. Elapsed Time = 2.26
# Reading Tweet 684/2356. (29.0%) complete. Elapsed Time = 1.92
# Reading Tweet 685/2356. (29.1%) complete. Elapsed Time = 2.39
# Reading Tweet 686/2356. (29.1%) complete. Elapsed Time = 2.45
# Reading Tweet 687/2356. (29.2%) complete. Elapsed Time = 1.84
# Reading Tweet 688/2356. (29.2%) complete. Elapsed Time = 2.04
# Reading Tweet 689/2356. (29.2%) complete. Elapsed Time = 1.25
# Reading Tweet 690/2356. (29.3%) complete. Elapsed Time = 2.23
# Reading Tweet 691/2356. (29.3%) complete. Elapsed Time = 1.7
# Reading Tweet 692/2356. (29.4%) complete. Elapsed Time = 1.63
# Reading Tweet 693/2356. (29.4%) complete. Elapsed Time = 1.2
# Reading Tweet 694/2356. (29.5%) complete. Elapsed Time = 1.15
# Reading Tweet 695/2356. (29.5%) complete. Elapsed Time = 1.02
# Reading Tweet 696/2356. (29.5%) complete. Elapsed Time = 1.12
# Reading Tweet 697/2356. (29.6%) complete. Elapsed Time = 1.11
# Reading Tweet 698/2356. (29.6%) complete. Elapsed Time = 1.3
# Reading Tweet 699/2356. (29.7%) complete. Elapsed Time = 2.25
# Reading Tweet 700/2356. (29.7%) complete. Elapsed Time = 1.81
# Reading Tweet 701/2356. (29.8%) complete. Elapsed Time = 1.26
# Reading Tweet 702/2356. (29.8%) complete. Elapsed Time = 1.65
# Reading Tweet 703/2356. (29.8%) complete. Elapsed Time = 1.42
# Reading Tweet 704/2356. (29.9%) complete. Elapsed Time = 1.44
# Reading Tweet 705/2356. (29.9%) complete. Elapsed Time = 2.13
# Reading Tweet 706/2356. (30.0%) complete. Elapsed Time = 1.16
# Reading Tweet 707/2356. (30.0%) complete. Elapsed Time = 2.14
# Reading Tweet 708/2356. (30.1%) complete. Elapsed Time = 1.75
# Reading Tweet 709/2356. (30.1%) complete. Elapsed Time = 1.84
# Reading Tweet 710/2356. (30.1%) complete. Elapsed Time = 1.63
# Reading Tweet 711/2356. (30.2%) complete. Elapsed Time = 1.84
# Reading Tweet 712/2356. (30.2%) complete. Elapsed Time = 1.85
# Reading Tweet 713/2356. (30.3%) complete. Elapsed Time = 1.96
# Reading Tweet 714/2356. (30.3%) complete. Elapsed Time = 1.73
# Reading Tweet 715/2356. (30.3%) complete. Elapsed Time = 1.52
# Reading Tweet 716/2356. (30.4%) complete. Elapsed Time = 1.96
# Reading Tweet 717/2356. (30.4%) complete. Elapsed Time = 1.58
# Reading Tweet 718/2356. (30.5%) complete. Elapsed Time = 1.39
# Reading Tweet 719/2356. (30.5%) complete. Elapsed Time = 1.95
# Reading Tweet 720/2356. (30.6%) complete. Elapsed Time = 1.85
# Reading Tweet 721/2356. (30.6%) complete. Elapsed Time = 1.88
# Reading Tweet 722/2356. (30.6%) complete. Elapsed Time = 1.45
# Reading Tweet 723/2356. (30.7%) complete. Elapsed Time = 1.17
# Reading Tweet 724/2356. (30.7%) complete. Elapsed Time = 1.63
# Reading Tweet 725/2356. (30.8%) complete. Elapsed Time = 1.74
# Reading Tweet 726/2356. (30.8%) complete. Elapsed Time = 1.36
# Reading Tweet 727/2356. (30.9%) complete. Elapsed Time = 1.28
# Reading Tweet 728/2356. (30.9%) complete. Elapsed Time = 1.57
# Reading Tweet 729/2356. (30.9%) complete. Elapsed Time = 2.04
# Reading Tweet 730/2356. (31.0%) complete. Elapsed Time = 1.74
# Reading Tweet 731/2356. (31.0%) complete. Elapsed Time = 1.58
# Reading Tweet 732/2356. (31.1%) complete. Elapsed Time = 1.8
# Reading Tweet 733/2356. (31.1%) complete. Elapsed Time = 1.83
# Reading Tweet 734/2356. (31.2%) complete. Elapsed Time = 2.05
# Reading Tweet 735/2356. (31.2%) complete. Elapsed Time = 1.84
# Reading Tweet 736/2356. (31.2%) complete. Elapsed Time = 2.05
# Reading Tweet 737/2356. (31.3%) complete. Elapsed Time = 2.46
# Reading Tweet 738/2356. (31.3%) complete. Elapsed Time = 1.85
# Reading Tweet 739/2356. (31.4%) complete. Elapsed Time = 2.26
# Reading Tweet 740/2356. (31.4%) complete. Elapsed Time = 1.64
# Reading Tweet 741/2356. (31.5%) complete. Elapsed Time = 1.63
# Reading Tweet 742/2356. (31.5%) complete. Elapsed Time = 1.85
# Reading Tweet 743/2356. (31.5%) complete. Elapsed Time = 1.84
# Reading Tweet 744/2356. (31.6%) complete. Elapsed Time = 1.58
# Reading Tweet 745/2356. (31.6%) complete. Elapsed Time = 1.43
# Reading Tweet 746/2356. (31.7%) complete. Elapsed Time = 1.5
# Reading Tweet 747/2356. (31.7%) complete. Elapsed Time = 1.32
# Reading Tweet 748/2356. (31.7%) complete. Elapsed Time = 1.83
# Reading Tweet 749/2356. (31.8%) complete. Elapsed Time = 1.27
# Reading Tweet 750/2356. (31.8%) complete. Elapsed Time = 1.68
# 779123168116150273[{'code': 144, 'message': 'No status found with that ID.'}]
# Reading Tweet 752/2356. (31.9%) complete. Elapsed Time = 1.89
# Reading Tweet 753/2356. (32.0%) complete. Elapsed Time = 2.03
# Reading Tweet 754/2356. (32.0%) complete. Elapsed Time = 1.87
# Reading Tweet 755/2356. (32.0%) complete. Elapsed Time = 2.25
# Reading Tweet 756/2356. (32.1%) complete. Elapsed Time = 1.42
# Reading Tweet 757/2356. (32.1%) complete. Elapsed Time = 1.44
# Reading Tweet 758/2356. (32.2%) complete. Elapsed Time = 1.53
# Reading Tweet 759/2356. (32.2%) complete. Elapsed Time = 1.75
# Reading Tweet 760/2356. (32.3%) complete. Elapsed Time = 1.84
# Reading Tweet 761/2356. (32.3%) complete. Elapsed Time = 2.24
# Reading Tweet 762/2356. (32.3%) complete. Elapsed Time = 1.65
# Reading Tweet 763/2356. (32.4%) complete. Elapsed Time = 1.7
# Reading Tweet 764/2356. (32.4%) complete. Elapsed Time = 1.97
# Reading Tweet 765/2356. (32.5%) complete. Elapsed Time = 2.05
# Reading Tweet 766/2356. (32.5%) complete. Elapsed Time = 1.85
# Reading Tweet 767/2356. (32.6%) complete. Elapsed Time = 1.64
# Reading Tweet 768/2356. (32.6%) complete. Elapsed Time = 2.1
# Reading Tweet 769/2356. (32.6%) complete. Elapsed Time = 1.43
# Reading Tweet 770/2356. (32.7%) complete. Elapsed Time = 1.79
# Reading Tweet 771/2356. (32.7%) complete. Elapsed Time = 1.85
# Reading Tweet 772/2356. (32.8%) complete. Elapsed Time = 2.05
# Reading Tweet 773/2356. (32.8%) complete. Elapsed Time = 1.52
# Reading Tweet 774/2356. (32.9%) complete. Elapsed Time = 1.63
# Reading Tweet 775/2356. (32.9%) complete. Elapsed Time = 1.76
# ...
# Reading Tweet 2104/2356. (89.3%) complete. Elapsed Time = 1.14
# Reading Tweet 2105/2356. (89.3%) complete. Elapsed Time = 1.28
# Reading Tweet 2106/2356. (89.4%) complete. Elapsed Time = 1.69
# Reading Tweet 2107/2356. (89.4%) complete. Elapsed Time = 1.44
# Reading Tweet 2108/2356. (89.5%) complete. Elapsed Time = 1.24
# Reading Tweet 2109/2356. (89.5%) complete. Elapsed Time = 1.18
# Reading Tweet 2110/2356. (89.6%) complete. Elapsed Time = 1.89
# Reading Tweet 2111/2356. (89.6%) complete. Elapsed Time = 1.28
# Reading Tweet 2112/2356. (89.6%) complete. Elapsed Time = 1.57
# Reading Tweet 2113/2356. (89.7%) complete. Elapsed Time = 1.72
# Reading Tweet 2114/2356. (89.7%) complete. Elapsed Time = 1.83
# Reading Tweet 2115/2356. (89.8%) complete. Elapsed Time = 1.45
# Reading Tweet 2116/2356. (89.8%) complete. Elapsed Time = 2.12
# Reading Tweet 2117/2356. (89.9%) complete. Elapsed Time = 1.72
# Reading Tweet 2118/2356. (89.9%) complete. Elapsed Time = 1.48
# Reading Tweet 2119/2356. (89.9%) complete. Elapsed Time = 2.25
# Reading Tweet 2120/2356. (90.0%) complete. Elapsed Time = 1.64
# Reading Tweet 2121/2356. (90.0%) complete. Elapsed Time = 1.79
# Reading Tweet 2122/2356. (90.1%) complete. Elapsed Time = 2.09
# Reading Tweet 2123/2356. (90.1%) complete. Elapsed Time = 1.85
# Reading Tweet 2124/2356. (90.2%) complete. Elapsed Time = 2.25
# Reading Tweet 2125/2356. (90.2%) complete. Elapsed Time = 1.84
# Reading Tweet 2126/2356. (90.2%) complete. Elapsed Time = 2.04
# Reading Tweet 2127/2356. (90.3%) complete. Elapsed Time = 2.39
# Reading Tweet 2128/2356. (90.3%) complete. Elapsed Time = 1.72
# Reading Tweet 2129/2356. (90.4%) complete. Elapsed Time = 1.64
# Reading Tweet 2130/2356. (90.4%) complete. Elapsed Time = 2.25
# Reading Tweet 2131/2356. (90.4%) complete. Elapsed Time = 1.8
# Reading Tweet 2132/2356. (90.5%) complete. Elapsed Time = 2.17
# Reading Tweet 2133/2356. (90.5%) complete. Elapsed Time = 2.06
# Reading Tweet 2134/2356. (90.6%) complete. Elapsed Time = 3.44
# Reading Tweet 2135/2356. (90.6%) complete. Elapsed Time = 1.93
# Reading Tweet 2136/2356. (90.7%) complete. Elapsed Time = 1.08
# Reading Tweet 2137/2356. (90.7%) complete. Elapsed Time = 1.38
# Reading Tweet 2138/2356. (90.7%) complete. Elapsed Time = 1.13
# Reading Tweet 2139/2356. (90.8%) complete. Elapsed Time = 1.23
# Reading Tweet 2140/2356. (90.8%) complete. Elapsed Time = 1.57
# Reading Tweet 2141/2356. (90.9%) complete. Elapsed Time = 1.93
# Reading Tweet 2142/2356. (90.9%) complete. Elapsed Time = 1.77
# Reading Tweet 2143/2356. (91.0%) complete. Elapsed Time = 1.84
# Reading Tweet 2144/2356. (91.0%) complete. Elapsed Time = 2.25
# Reading Tweet 2145/2356. (91.0%) complete. Elapsed Time = 2.46
# Reading Tweet 2146/2356. (91.1%) complete. Elapsed Time = 2.05
# Reading Tweet 2147/2356. (91.1%) complete. Elapsed Time = 2.25
# Reading Tweet 2148/2356. (91.2%) complete. Elapsed Time = 1.82
# Reading Tweet 2149/2356. (91.2%) complete. Elapsed Time = 1.63
# Reading Tweet 2150/2356. (91.3%) complete. Elapsed Time = 1.67
# Reading Tweet 2151/2356. (91.3%) complete. Elapsed Time = 2.23
# Reading Tweet 2152/2356. (91.3%) complete. Elapsed Time = 2.47
# Reading Tweet 2153/2356. (91.4%) complete. Elapsed Time = 1.51
# Reading Tweet 2154/2356. (91.4%) complete. Elapsed Time = 1.55
# Reading Tweet 2155/2356. (91.5%) complete. Elapsed Time = 2.05
# Reading Tweet 2156/2356. (91.5%) complete. Elapsed Time = 2.09
# Reading Tweet 2157/2356. (91.6%) complete. Elapsed Time = 1.79
# Reading Tweet 2158/2356. (91.6%) complete. Elapsed Time = 2.88
# Reading Tweet 2159/2356. (91.6%) complete. Elapsed Time = 1.84
# Reading Tweet 2160/2356. (91.7%) complete. Elapsed Time = 1.47
# Reading Tweet 2161/2356. (91.7%) complete. Elapsed Time = 1.67
# Reading Tweet 2162/2356. (91.8%) complete. Elapsed Time = 1.27
# Reading Tweet 2163/2356. (91.8%) complete. Elapsed Time = 1.32
# Reading Tweet 2164/2356. (91.9%) complete. Elapsed Time = 2.25
# Reading Tweet 2165/2356. (91.9%) complete. Elapsed Time = 1.63
# Reading Tweet 2166/2356. (91.9%) complete. Elapsed Time = 2.25
# Reading Tweet 2167/2356. (92.0%) complete. Elapsed Time = 1.22
# Reading Tweet 2168/2356. (92.0%) complete. Elapsed Time = 2.05
# Reading Tweet 2169/2356. (92.1%) complete. Elapsed Time = 2.05
# Reading Tweet 2170/2356. (92.1%) complete. Elapsed Time = 1.66
# Reading Tweet 2171/2356. (92.1%) complete. Elapsed Time = 2.03
# Reading Tweet 2172/2356. (92.2%) complete. Elapsed Time = 1.85
# Reading Tweet 2173/2356. (92.2%) complete. Elapsed Time = 1.43
# Reading Tweet 2174/2356. (92.3%) complete. Elapsed Time = 1.85
# Reading Tweet 2175/2356. (92.3%) complete. Elapsed Time = 1.84
# Reading Tweet 2176/2356. (92.4%) complete. Elapsed Time = 1.23
# Reading Tweet 2177/2356. (92.4%) complete. Elapsed Time = 1.84
# Reading Tweet 2178/2356. (92.4%) complete. Elapsed Time = 1.84
# Reading Tweet 2179/2356. (92.5%) complete. Elapsed Time = 2.25
# Reading Tweet 2180/2356. (92.5%) complete. Elapsed Time = 1.83
# Reading Tweet 2181/2356. (92.6%) complete. Elapsed Time = 1.66
# Reading Tweet 2182/2356. (92.6%) complete. Elapsed Time = 2.44
# Reading Tweet 2183/2356. (92.7%) complete. Elapsed Time = 2.25
# Reading Tweet 2184/2356. (92.7%) complete. Elapsed Time = 1.43
# Reading Tweet 2185/2356. (92.7%) complete. Elapsed Time = 1.49
# Reading Tweet 2186/2356. (92.8%) complete. Elapsed Time = 2.05
# Reading Tweet 2187/2356. (92.8%) complete. Elapsed Time = 1.11
# Reading Tweet 2188/2356. (92.9%) complete. Elapsed Time = 1.16
# Reading Tweet 2189/2356. (92.9%) complete. Elapsed Time = 1.82
# Reading Tweet 2190/2356. (93.0%) complete. Elapsed Time = 1.77
# Reading Tweet 2191/2356. (93.0%) complete. Elapsed Time = 1.57
# Reading Tweet 2192/2356. (93.0%) complete. Elapsed Time = 2.33
# Reading Tweet 2193/2356. (93.1%) complete. Elapsed Time = 1.63
# Reading Tweet 2194/2356. (93.1%) complete. Elapsed Time = 1.75
# Reading Tweet 2195/2356. (93.2%) complete. Elapsed Time = 2.25
# Reading Tweet 2196/2356. (93.2%) complete. Elapsed Time = 2.26
# Reading Tweet 2197/2356. (93.3%) complete. Elapsed Time = 2.34
# Reading Tweet 2198/2356. (93.3%) complete. Elapsed Time = 2.25
# Reading Tweet 2199/2356. (93.3%) complete. Elapsed Time = 2.26
# Reading Tweet 2200/2356. (93.4%) complete. Elapsed Time = 1.64
# Reading Tweet 2201/2356. (93.4%) complete. Elapsed Time = 1.84
# Reading Tweet 2202/2356. (93.5%) complete. Elapsed Time = 1.64
# Reading Tweet 2203/2356. (93.5%) complete. Elapsed Time = 2.05
# Reading Tweet 2204/2356. (93.5%) complete. Elapsed Time = 1.84
# Reading Tweet 2205/2356. (93.6%) complete. Elapsed Time = 1.49
# Reading Tweet 2206/2356. (93.6%) complete. Elapsed Time = 1.55
# Reading Tweet 2207/2356. (93.7%) complete. Elapsed Time = 1.9
# Reading Tweet 2208/2356. (93.7%) complete. Elapsed Time = 1.41
# Reading Tweet 2209/2356. (93.8%) complete. Elapsed Time = 1.84
# Reading Tweet 2210/2356. (93.8%) complete. Elapsed Time = 2.15
# Reading Tweet 2211/2356. (93.8%) complete. Elapsed Time = 2.35
# Reading Tweet 2212/2356. (93.9%) complete. Elapsed Time = 1.63
# Reading Tweet 2213/2356. (93.9%) complete. Elapsed Time = 1.7
# Reading Tweet 2214/2356. (94.0%) complete. Elapsed Time = 1.99
# Reading Tweet 2215/2356. (94.0%) complete. Elapsed Time = 2.05
# Reading Tweet 2216/2356. (94.1%) complete. Elapsed Time = 1.82
# Reading Tweet 2217/2356. (94.1%) complete. Elapsed Time = 1.19
# Reading Tweet 2218/2356. (94.1%) complete. Elapsed Time = 1.72
# Reading Tweet 2219/2356. (94.2%) complete. Elapsed Time = 1.79
# Reading Tweet 2220/2356. (94.2%) complete. Elapsed Time = 1.31
# Reading Tweet 2221/2356. (94.3%) complete. Elapsed Time = 1.2
# Reading Tweet 2222/2356. (94.3%) complete. Elapsed Time = 1.11
# Reading Tweet 2223/2356. (94.4%) complete. Elapsed Time = 1.33
# Reading Tweet 2224/2356. (94.4%) complete. Elapsed Time = 2.05
# Reading Tweet 2225/2356. (94.4%) complete. Elapsed Time = 2.25
# Reading Tweet 2226/2356. (94.5%) complete. Elapsed Time = 2.25
# Reading Tweet 2227/2356. (94.5%) complete. Elapsed Time = 1.85
# Reading Tweet 2228/2356. (94.6%) complete. Elapsed Time = 1.48
# Reading Tweet 2229/2356. (94.6%) complete. Elapsed Time = 1.79
# Reading Tweet 2230/2356. (94.7%) complete. Elapsed Time = 1.65
# Reading Tweet 2231/2356. (94.7%) complete. Elapsed Time = 1.84
# Reading Tweet 2232/2356. (94.7%) complete. Elapsed Time = 2.45
# Reading Tweet 2233/2356. (94.8%) complete. Elapsed Time = 2.05
# Reading Tweet 2234/2356. (94.8%) complete. Elapsed Time = 1.64
# Reading Tweet 2235/2356. (94.9%) complete. Elapsed Time = 1.47
# Reading Tweet 2236/2356. (94.9%) complete. Elapsed Time = 1.2
# Reading Tweet 2237/2356. (94.9%) complete. Elapsed Time = 2.03
# Reading Tweet 2238/2356. (95.0%) complete. Elapsed Time = 1.55
# Reading Tweet 2239/2356. (95.0%) complete. Elapsed Time = 1.68
# Reading Tweet 2240/2356. (95.1%) complete. Elapsed Time = 1.95
# Reading Tweet 2241/2356. (95.1%) complete. Elapsed Time = 1.77
# Reading Tweet 2242/2356. (95.2%) complete. Elapsed Time = 1.43
# Reading Tweet 2243/2356. (95.2%) complete. Elapsed Time = 2.69
# Reading Tweet 2244/2356. (95.2%) complete. Elapsed Time = 4.53
# Reading Tweet 2245/2356. (95.3%) complete. Elapsed Time = 3.07
# Reading Tweet 2246/2356. (95.3%) complete. Elapsed Time = 1.38
# Reading Tweet 2247/2356. (95.4%) complete. Elapsed Time = 2.04
# Reading Tweet 2248/2356. (95.4%) complete. Elapsed Time = 1.84
# Reading Tweet 2249/2356. (95.5%) complete. Elapsed Time = 1.64
# Reading Tweet 2250/2356. (95.5%) complete. Elapsed Time = 2.05
# Reading Tweet 2251/2356. (95.5%) complete. Elapsed Time = 2.04
# Reading Tweet 2252/2356. (95.6%) complete. Elapsed Time = 2.25
# Reading Tweet 2253/2356. (95.6%) complete. Elapsed Time = 1.64
# Reading Tweet 2254/2356. (95.7%) complete. Elapsed Time = 1.57
# Reading Tweet 2255/2356. (95.7%) complete. Elapsed Time = 1.91
# Reading Tweet 2256/2356. (95.8%) complete. Elapsed Time = 1.23
# Reading Tweet 2257/2356. (95.8%) complete. Elapsed Time = 2.05
# Reading Tweet 2258/2356. (95.8%) complete. Elapsed Time = 2.23
# Reading Tweet 2259/2356. (95.9%) complete. Elapsed Time = 2.48
# Reading Tweet 2260/2356. (95.9%) complete. Elapsed Time = 1.56
# Reading Tweet 2261/2356. (96.0%) complete. Elapsed Time = 1.31
# Reading Tweet 2262/2356. (96.0%) complete. Elapsed Time = 2.24
# Reading Tweet 2263/2356. (96.1%) complete. Elapsed Time = 2.26
# Reading Tweet 2264/2356. (96.1%) complete. Elapsed Time = 1.58
# Reading Tweet 2265/2356. (96.1%) complete. Elapsed Time = 1.69
# Reading Tweet 2266/2356. (96.2%) complete. Elapsed Time = 2.46
# Reading Tweet 2267/2356. (96.2%) complete. Elapsed Time = 1.64
# Reading Tweet 2268/2356. (96.3%) complete. Elapsed Time = 2.25
# Reading Tweet 2269/2356. (96.3%) complete. Elapsed Time = 1.26
# Reading Tweet 2270/2356. (96.3%) complete. Elapsed Time = 2.01
# Reading Tweet 2271/2356. (96.4%) complete. Elapsed Time = 2.05
# Reading Tweet 2272/2356. (96.4%) complete. Elapsed Time = 1.31
# Reading Tweet 2273/2356. (96.5%) complete. Elapsed Time = 1.34
# Reading Tweet 2274/2356. (96.5%) complete. Elapsed Time = 2.25
# Reading Tweet 2275/2356. (96.6%) complete. Elapsed Time = 1.84
# Reading Tweet 2276/2356. (96.6%) complete. Elapsed Time = 1.64
# Reading Tweet 2277/2356. (96.6%) complete. Elapsed Time = 2.25
# Reading Tweet 2278/2356. (96.7%) complete. Elapsed Time = 2.25
# Reading Tweet 2279/2356. (96.7%) complete. Elapsed Time = 2.05
# Reading Tweet 2280/2356. (96.8%) complete. Elapsed Time = 1.84
# Reading Tweet 2281/2356. (96.8%) complete. Elapsed Time = 2.26
# Reading Tweet 2282/2356. (96.9%) complete. Elapsed Time = 2.26
# Reading Tweet 2283/2356. (96.9%) complete. Elapsed Time = 2.45
# Reading Tweet 2284/2356. (96.9%) complete. Elapsed Time = 2.05
# Reading Tweet 2285/2356. (97.0%) complete. Elapsed Time = 1.84
# Reading Tweet 2286/2356. (97.0%) complete. Elapsed Time = 2.25
# Reading Tweet 2287/2356. (97.1%) complete. Elapsed Time = 1.84
# Reading Tweet 2288/2356. (97.1%) complete. Elapsed Time = 2.32
# Reading Tweet 2289/2356. (97.2%) complete. Elapsed Time = 1.56
# Reading Tweet 2290/2356. (97.2%) complete. Elapsed Time = 2.25
# Reading Tweet 2291/2356. (97.2%) complete. Elapsed Time = 1.64
# Reading Tweet 2292/2356. (97.3%) complete. Elapsed Time = 2.35
# Reading Tweet 2293/2356. (97.3%) complete. Elapsed Time = 1.84
# Reading Tweet 2294/2356. (97.4%) complete. Elapsed Time = 1.94
# Reading Tweet 2295/2356. (97.4%) complete. Elapsed Time = 1.61
# Reading Tweet 2296/2356. (97.5%) complete. Elapsed Time = 1.5
# Reading Tweet 2297/2356. (97.5%) complete. Elapsed Time = 1.29
# Reading Tweet 2298/2356. (97.5%) complete. Elapsed Time = 1.73
# Reading Tweet 2299/2356. (97.6%) complete. Elapsed Time = 1.67
# Reading Tweet 2300/2356. (97.6%) complete. Elapsed Time = 1.37
# Reading Tweet 2301/2356. (97.7%) complete. Elapsed Time = 1.83
# Reading Tweet 2302/2356. (97.7%) complete. Elapsed Time = 1.63
# Reading Tweet 2303/2356. (97.8%) complete. Elapsed Time = 1.43
# Reading Tweet 2304/2356. (97.8%) complete. Elapsed Time = 1.59
# Reading Tweet 2305/2356. (97.8%) complete. Elapsed Time = 1.56
# Reading Tweet 2306/2356. (97.9%) complete. Elapsed Time = 2.24
# Reading Tweet 2307/2356. (97.9%) complete. Elapsed Time = 1.77
# Reading Tweet 2308/2356. (98.0%) complete. Elapsed Time = 2.33
# Reading Tweet 2309/2356. (98.0%) complete. Elapsed Time = 2.04
# Reading Tweet 2310/2356. (98.0%) complete. Elapsed Time = 1.84
# Reading Tweet 2311/2356. (98.1%) complete. Elapsed Time = 1.87
# Reading Tweet 2312/2356. (98.1%) complete. Elapsed Time = 1.5
# Reading Tweet 2313/2356. (98.2%) complete. Elapsed Time = 1.74
# Reading Tweet 2314/2356. (98.2%) complete. Elapsed Time = 2.04
# Reading Tweet 2315/2356. (98.3%) complete. Elapsed Time = 1.86
# Reading Tweet 2316/2356. (98.3%) complete. Elapsed Time = 1.84
# Reading Tweet 2317/2356. (98.3%) complete. Elapsed Time = 1.84
# Reading Tweet 2318/2356. (98.4%) complete. Elapsed Time = 2.66
# Reading Tweet 2319/2356. (98.4%) complete. Elapsed Time = 2.05
# Reading Tweet 2320/2356. (98.5%) complete. Elapsed Time = 1.64
# Reading Tweet 2321/2356. (98.5%) complete. Elapsed Time = 2.08
# Reading Tweet 2322/2356. (98.6%) complete. Elapsed Time = 1.81
# Reading Tweet 2323/2356. (98.6%) complete. Elapsed Time = 2.25
# Reading Tweet 2324/2356. (98.6%) complete. Elapsed Time = 2.03
# Reading Tweet 2325/2356. (98.7%) complete. Elapsed Time = 1.13
# Reading Tweet 2326/2356. (98.7%) complete. Elapsed Time = 1.62
# Reading Tweet 2327/2356. (98.8%) complete. Elapsed Time = 1.44
# Reading Tweet 2328/2356. (98.8%) complete. Elapsed Time = 1.76
# Reading Tweet 2329/2356. (98.9%) complete. Elapsed Time = 1.47
# Reading Tweet 2330/2356. (98.9%) complete. Elapsed Time = 1.17
# Reading Tweet 2331/2356. (98.9%) complete. Elapsed Time = 1.58
# Reading Tweet 2332/2356. (99.0%) complete. Elapsed Time = 1.52
# Reading Tweet 2333/2356. (99.0%) complete. Elapsed Time = 1.59
# Reading Tweet 2334/2356. (99.1%) complete. Elapsed Time = 1.89
# Reading Tweet 2335/2356. (99.1%) complete. Elapsed Time = 2.05
# Reading Tweet 2336/2356. (99.2%) complete. Elapsed Time = 1.49
# Reading Tweet 2337/2356. (99.2%) complete. Elapsed Time = 1.79
# Reading Tweet 2338/2356. (99.2%) complete. Elapsed Time = 1.84
# Reading Tweet 2339/2356. (99.3%) complete. Elapsed Time = 2.86
# Reading Tweet 2340/2356. (99.3%) complete. Elapsed Time = 2.25
# Reading Tweet 2341/2356. (99.4%) complete. Elapsed Time = 2.26
# Reading Tweet 2342/2356. (99.4%) complete. Elapsed Time = 1.63
# Reading Tweet 2343/2356. (99.4%) complete. Elapsed Time = 2.25
# Reading Tweet 2344/2356. (99.5%) complete. Elapsed Time = 2.08
# Reading Tweet 2345/2356. (99.5%) complete. Elapsed Time = 1.29
# Reading Tweet 2346/2356. (99.6%) complete. Elapsed Time = 2.37
# Reading Tweet 2347/2356. (99.6%) complete. Elapsed Time = 1.85
# Reading Tweet 2348/2356. (99.7%) complete. Elapsed Time = 2.24
# Reading Tweet 2349/2356. (99.7%) complete. Elapsed Time = 2.26
# Reading Tweet 2350/2356. (99.7%) complete. Elapsed Time = 2.06
# Reading Tweet 2351/2356. (99.8%) complete. Elapsed Time = 2.44
# Reading Tweet 2352/2356. (99.8%) complete. Elapsed Time = 2.26
# Reading Tweet 2353/2356. (99.9%) complete. Elapsed Time = 2.37
# Reading Tweet 2354/2356. (99.9%) complete. Elapsed Time = 1.85
# Reading Tweet 2355/2356. (100.0%) complete. Elapsed Time = 1.63
# Reading Tweet 2356/2356. (100.0%) complete. Elapsed Time = 2.14
# Reading Process Completed. Elapsed Time is 73:52

# %%
errors_list
# Out:
# [888202515573088257,
#  873697596434513921,
#  872668790621863937,
#  872261713294495745,
#  869988702071779329,
#  866816280283807744,
#  861769973181624320,
#  856602993587888130,
#  851953902622658560,
#  845459076796616705,
#  844704788403113984,
#  842892208864923648,
#  837366284874571778,
#  837012587749474308,
#  829374341691346946,
#  827228250799742977,
#  812747805718642688,
#  802247111496568832,
#  779123168116150273,
#  775096608509886464,
#  771004394259247104,
#  770743923962707968,
#  759566828574212096,
#  754011816964026368,
#  680055455951884288]

# %%
# save df of queried tweets to JSON and then convert to a dataframe
df_json = pd.DataFrame(df_list, columns = ['tweet_id', 'retweet_count', 'favorite_count'])
df_json.to_json('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/tweet_json.txt')
df_json = pd.read_json('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/tweet_json.txt')
df_json.head()
# Out:
#       favorite_count  retweet_count            tweet_id
# 0              38044           8321  892420643555336193
# 1              32670           6148  892177421306343426
# 10             30108           7178  890006608113172480
# 100            40160           8939  872486979161796608
# 1000           10070           4280  747103485104099331

# %% [markdown]
# ## Assess Data

# %% [markdown]
# ### **df_twitter_archive assessments**<br />

# %%
df_twitter_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
df_twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 803   772152991789019136                    NaN                  NaN
# 0     892420643555336193                    NaN                  NaN
# 1154  725458796924002305                    NaN                  NaN
# 2229  668248472370458624                    NaN                  NaN
# 308   835574547218894849                    NaN                  NaN
# 815   771004394259247104                    NaN                  NaN
# 2080  670823764196741120                    NaN                  NaN
# 317   834786237630337024                    NaN                  NaN
# 1458  695074328191332352                    NaN                  NaN
# 1572  687664829264453632                    NaN                  NaN
#
#                       timestamp  \
# 803   2016-09-03 19:23:13 +0000
# 0     2017-08-01 16:23:56 +0000
# 1154  2016-04-27 22:57:10 +0000
# 2229  2015-11-22 02:03:45 +0000
# 308   2017-02-25 19:37:50 +0000
# 815   2016-08-31 15:19:06 +0000
# 2080  2015-11-29 04:37:03 +0000
# 317   2017-02-23 15:25:23 +0000
# 1458  2016-02-04 02:40:08 +0000
# 1572  2016-01-14 15:57:26 +0000
#
#                                                  source  \
# 803   <a href="http://twitter.com/download/iphone" r...
# 0     <a href="http://twitter.com/download/iphone" r...
# 1154  <a href="http://twitter.com/download/iphone" r...
# 2229  <a href="http://twitter.com/download/iphone" r...
# 308   <a href="http://twitter.com/download/iphone" r...
# 815   <a href="http://twitter.com/download/iphone" r...
# 2080  <a href="http://twitter.com/download/iphone" r...
# 317   <a href="http://twitter.com/download/iphone" r...
# 1458  <a href="http://twitter.com/download/iphone" r...
# 1572  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 803   Here's a couple rufferees making sure all the ...                  NaN
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1154  Pup had to be removed cuz it wouldn't have bee...                  NaN
# 2229  Say hello to Bisquick. He is a Brown Douglass ...                  NaN
# 308   This is Eli. He works backstage at Bone Jovi c...                  NaN
# 815   RT @katieornah: @dog_rates learning a lot at c...         7.710021e+17
# 2080  This is Remington. He's a man dime. 12/10 http...                  NaN
# 317   This is Tobi. She is properly fetching her sho...                  NaN
# 1458  This is Lorenzo. He's educated af. Just gradua...                  NaN
# 1572  Meet Opal. He's a Belgian Dijon Poofster. Upse...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 803                        NaN                        NaN
# 0                          NaN                        NaN
# 1154                       NaN                        NaN
# 2229                       NaN                        NaN
# 308                        NaN                        NaN
# 815               1.732729e+09  2016-08-31 15:10:07 +0000
# 2080                       NaN                        NaN
# 317                        NaN                        NaN
# 1458                       NaN                        NaN
# 1572                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 803   https://twitter.com/dog_rates/status/772152991...                10
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1154  https://twitter.com/foxdeportes/status/7251360...                13
# 2229  https://twitter.com/dog_rates/status/668248472...                 8
# 308   https://twitter.com/dog_rates/status/835574547...                11
# 815   https://twitter.com/katieornah/status/77100213...                12
# 2080  https://twitter.com/dog_rates/status/670823764...                12
# 317   https://twitter.com/dog_rates/status/834786237...                13
# 1458  https://twitter.com/dog_rates/status/695074328...                11
# 1572  https://twitter.com/dog_rates/status/687664829...                11
#
#       rating_denominator       name doggo floofer  pupper puppo
# 803                   10       None  None    None    None  None
# 0                     10    Phineas  None    None    None  None
# 1154                  10       None  None    None    None  None
# 2229                  10   Bisquick  None    None    None  None
# 308                   10        Eli  None    None    None  None
# 815                   10       None  None    None  pupper  None
# 2080                  10  Remington  None    None    None  None
# 317                   10       Tobi  None    None    None  None
# 1458                  10    Lorenzo  None    None  pupper  None
# 1572                  10       Opal  None    None    None  None

# %%
df_twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
df_twitter_archive['expanded_urls'].isnull().sum()
# Out:
# 59

# %%
df_twitter_archive['name'].value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Cooper      11
# Lucy        11
#           ...
# Timofy       1
# Newt         1
# Dudley       1
# Ulysses      1
# Richie       1
# Name: name, Length: 957, dtype: int64

# %%
df_twitter_archive['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
df_twitter_archive['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
df_twitter_archive['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# **observations**
#
# quality issues:
# - Name column has "None", "a", "the", and "an" names that are not real names
# - timestamp date is incorrect format(unecessary +0000 in date). The timestamp data type is wrong; object should be changed to time
# - data type of tweet_id should be string instead of object
# - there are 59 null entries in the expanded_urls column
# - rating_denominator column should only have one denominator value - 10
# - rating_numerator have values lower than 10 that should be removed.
# - some ratings can be extracted from the text of the tweet and be used to fill in the rating_numerator column<br />
#
# tidiness issues:<br />
# - in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, and retweeted_status_timestamp columns have null values in them. This is an issue because we want only the original tweets. We will drop these columns later in the project.

# %% [markdown]
# ### **image_predictions assessments**

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1161  734787690684657664  https://pbs.twimg.com/media/CjJ9gQ1WgAAXQtJ.jpg
# 482   675372240448454658  https://pbs.twimg.com/media/CV9nd30XAAAEba5.jpg
# 351   672523490734551040  https://pbs.twimg.com/media/CVVIjGbWwAAxkN0.jpg
# 1899  851224888060895234  https://pbs.twimg.com/media/C9AohFoWsAUmxDs.jpg
# 1599  799422933579902976  https://pbs.twimg.com/media/Cxge6AdUQAAvXLB.jpg
# 196   669597912108789760  https://pbs.twimg.com/media/CUrjvxiVEAA94dH.jpg
# 445   674646392044941312  https://pbs.twimg.com/media/CVzTUGrW4AAirJH.jpg
# 1879  846514051647705089  https://pbs.twimg.com/media/C79sB4xXwAEvwKY.jpg
# 339   672245253877968896  https://pbs.twimg.com/media/CVRLfeoW4AA_ldZ.jpg
# 199   669661792646373376  https://pbs.twimg.com/media/CUsd2TfWwAAmdjb.jpg
#
#       img_num                     p1   p1_conf  p1_dog  \
# 1161        4       golden_retriever  0.883991    True
# 482         1              Chihuahua  0.416385    True
# 351         1       golden_retriever  0.565981    True
# 1899        3             car_mirror  0.971512   False
# 1599        1     miniature_pinscher  0.583630    True
# 196         1             Eskimo_dog  0.595665    True
# 445         1  flat-coated_retriever  0.837448    True
# 1879        2       golden_retriever  0.650003    True
# 339         1              Chihuahua  0.718944    True
# 199         1                 weasel  0.262802   False
#
#                                p2   p2_conf  p2_dog                  p3  \
# 1161                         chow  0.023542    True  Labrador_retriever
# 482   West_Highland_white_terrier  0.102933    True             Samoyed
# 351                          chow  0.081212    True       Irish_terrier
# 1899                    seat_belt  0.007063   False     standard_poodle
# 1599                      redbone  0.276095    True         toy_terrier
# 196                Siberian_husky  0.214474    True          white_wolf
# 445                   groenendael  0.086166    True  Labrador_retriever
# 1879                     Leonberg  0.065199    True     Norfolk_terrier
# 339                        badger  0.178546   False         toy_terrier
# 199                   Siamese_cat  0.148263   False             hamster
#
#        p3_conf  p3_dog
# 1161  0.016056    True
# 482   0.087300    True
# 351   0.061596    True
# 1899  0.005683    True
# 1599  0.018550    True
# 196   0.147235   False
# 445   0.016052    True
# 1879  0.052955    True
# 339   0.037103    True
# 199   0.116374   False

# %% [markdown]
# **observations** <br />
#
# quality issues:<br />
# - some names of dogs are capitalized and some are not in the p1, p2, and p3 columns
#
# tidiness issues: <br />
# - df_twitter_archive, image predictions, and df_json can be combined into one table since they all describe one tweet

# %% [markdown]
# ### **df_json assessments**

# %%
# save df of queried tweets to JSON and then convert to a dataframe
df_json = pd.DataFrame(df_list, columns = ['tweet_id', 'retweet_count', 'favorite_count'])
df_json.to_json('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/tweet_json.txt')
df_json = pd.read_json('D:/UDACITY project/udacity-DAND-master/udacity-DAND-master/p7/project/tweet_json.txt')
df_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           7723           36289
# 1  892177421306343426           5714           31293
# 2  891815181378084864           3786           23568
# 3  891689557279858688           7884           39589
# 4  891327558926688256           8502           37805

# %%
#df_json.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6f42a2d99c20> in <module>
# ----> 1 df_json.head()
#
# NameError: name 'df_json' is not defined

# %%
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
# tweet_id          2331 non-null int64
# retweet_count     2331 non-null int64
# favorite_count    2331 non-null int64
# dtypes: int64(3)
# memory usage: 72.8 KB

# %%
#df_json.info()

# %% [markdown]
# **observations**<br />
#
# tidiness issues: <br />
# - "Unamed: 0" column should be dropped since it is only an index column

# %% [markdown]
# ## Clean Data

# %%
# Make a copy of the dataframes before starting the cleaning process
df_twitter_archive_clean = df_twitter_archive.copy()
image_predictions_clean = image_predictions.copy()
df_json_clean = df_json.copy()

# %% [markdown]
# ### Clean 8 Quality Issues

# %% [markdown]
# **Issue #1:**<br />
#
# **Define** <br />
# Dog names "None", "a", "the" and "an" should be replaced

# %% [markdown]
# **Code**

# %%
# Replace the dog names that are not names to NaN. There are many more dog names that are not really dog names 
# but for this example, we will only clean the ones found in the value_counts listing from the assessments above
df_twitter_archive_clean['name'].replace("None", "NaN", inplace= True)
df_twitter_archive_clean['name'].replace("a", "NaN", inplace= True)
df_twitter_archive_clean['name'].replace("the", "NaN", inplace= True)
df_twitter_archive_clean['name'].replace("an", "NaN", inplace= True)

# %% [markdown]
# **Test**

# %%
'None' in df_twitter_archive_clean['name']
'a' in df_twitter_archive_clean['name']
'the' in df_twitter_archive_clean['name']
'an' in df_twitter_archive_clean['name']
# Out:
# False

# %% [markdown]
# **Issue #2:** <br />
#
# **Define**<br />
# Timestamp format is incorrect. Change timestamp data type from object to datetime. The +0000 will drop

# %% [markdown]
# **Code**

# %%
df_twitter_archive_clean['timestamp'] = pd.to_datetime(df_twitter_archive_clean['timestamp'])

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# **Issue #3:**<br />
#
# **Define** <br />
# Data type of tweet_id should be string, not object. We need to change the tweet_id of image_predictions_clean dataframe and df_json_clean dataframe to string as well.

# %% [markdown]
# **Code**

# %%
df_twitter_archive_clean.tweet_id = df_twitter_archive_clean.tweet_id.astype(str)
image_predictions_clean.tweet_id = image_predictions_clean.tweet_id.astype(str)
df_json_clean.tweet_id = df_json_clean.tweet_id.astype(str)

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns, UTC]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# **Issue #4:** <br />
#
# **Define**<br />
# The expanded_urls column has null values that need to be dropped. There are 59 total that we observed from the assessments.

# %% [markdown]
# **Code**

# %%
# Drop the null values in the expanded_urls column
df_twitter_archive_clean["expanded_urls"].dropna(inplace= True)

# %% [markdown]
# **Test**

# %%
"NaN" in df_twitter_archive_clean["expanded_urls"]
# Out:
# False

# %% [markdown]
# **Issue #5:** <br />
#
# **Define**<br />
# The rating_denominator column should only have the denominator 10

# %% [markdown]
# **Code**

# %%
df_twitter_archive_clean["rating_denominator"] = 10

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean.rating_denominator.value_counts()
# Out:
# 10    2356
# Name: rating_denominator, dtype: int64

# %% [markdown]
# **Issue #6:** <br />
#
# **Define**<br />
# The numerator column should exclude numbers less than 10 but just for an example, we will only exclude the values 0, 1, and 2. There should be 20 entries excluded based on the assessments we have done but because we have already started cleaning and dropping columns and rows, there are only 15 entries to be excluded now.

# %% [markdown]
# **Code**

# %%
# Recreate the dataframe by excluding the rating_numerator that are equal to 0, 1, and 2
df_twitter_archive_clean = df_twitter_archive_clean[df_twitter_archive_clean.rating_numerator != 0]
df_twitter_archive_clean = df_twitter_archive_clean[df_twitter_archive_clean.rating_numerator != 1]
df_twitter_archive_clean = df_twitter_archive_clean[df_twitter_archive_clean.rating_numerator != 2]

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 420       2
# 15        2
# 75        2
# 17        1
# 121       1
# 99        1
# 45        1
# 27        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 80        1
# 84        1
# 88        1
# 144       1
# 182       1
# 204       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 165       1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# **Issue #7:** <br />
#
# **Define**<br />
# We can extract numerator ratings from the tweet text and fill the missing values in rating_numerator column by finding the pattern ##.##

# %% [markdown]
# **Code**

# %%
df_twitter_archive_clean['rating_numerator'] = df_twitter_archive_clean.text.str.extract('(\d?\d*\.?\d\d*/)', expand=False)

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean[df_twitter_archive_clean['tweet_id']=='680494726643068929']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1712  680494726643068929                    NaN                  NaN
#
#                      timestamp  \
# 1712 2015-12-25 21:06:00+00:00
#
#                                                  source  \
# 1712  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1712  Here we have uncovered an entire battalion of ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1712                       NaN                        NaN
#
#                                           expanded_urls rating_numerator  \
# 1712  https://twitter.com/dog_rates/status/680494726...           11.26/
#
#       rating_denominator name doggo floofer pupper puppo
# 1712                  10  NaN  None    None   None  None

# %% [markdown]
# **Define**<br />
#
# Replace the / character from the rating_numerator column

# %% [markdown]
# **Code**

# %%
df_twitter_archive_clean['rating_numerator'].replace('/','', regex=True, inplace=True)

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean[df_twitter_archive_clean['tweet_id']=='680494726643068929']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1712  680494726643068929                    NaN                  NaN
#
#                      timestamp  \
# 1712 2015-12-25 21:06:00+00:00
#
#                                                  source  \
# 1712  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1712  Here we have uncovered an entire battalion of ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1712                       NaN                        NaN
#
#                                           expanded_urls rating_numerator  \
# 1712  https://twitter.com/dog_rates/status/680494726...            11.26
#
#       rating_denominator name doggo floofer pupper puppo
# 1712                  10  NaN  None    None   None  None

# %% [markdown]
# **Issue #8:** <br />
#
# **Define**<br />
# There are capitalized and lower cased names in the p1, p2, and p3 columns. Replace all dog names in these columns with a lower case letter.

# %% [markdown]
# **Code**

# %%
image_predictions_clean['p1'] = image_predictions_clean['p1'].str.lower()
image_predictions_clean['p2'] = image_predictions_clean['p2'].str.lower()
image_predictions_clean['p3'] = image_predictions_clean['p3'].str.lower()

# %% [markdown]
# **Test**

# %%
image_predictions_clean.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 1465  778624900596654080  https://pbs.twimg.com/media/Cs47N3eWcAEmgiW.jpg
# 1618  802572683846291456  https://pbs.twimg.com/media/CyNPmJgXcAECPuB.jpg
# 209   669972011175813120  https://pbs.twimg.com/media/CUw3_QiUEAA8cT9.jpg
# 1646  808501579447930884  https://pbs.twimg.com/media/Czhf4XtVQAAIqpd.jpg
# 1996  874680097055178752  https://pbs.twimg.com/media/DCN85nGUwAAzG_q.jpg
# 180   669327207240699904  https://pbs.twimg.com/media/CUntin8WIAADmLk.jpg
# 637   681261549936340994  https://pbs.twimg.com/media/CXRTw_5WMAAUDVp.jpg
# 939   703769065844768768  https://pbs.twimg.com/media/CcRKOzyXEAQO_HN.jpg
# 420   674042553264685056  https://pbs.twimg.com/media/CVquIDRW4AEJrPk.jpg
# 1976  870308999962521604  https://pbs.twimg.com/media/DBP1asiUAAEKZI5.jpg
#
#       img_num                          p1   p1_conf  p1_dog  \
# 1465        2                    airedale  0.786089    True
# 1618        1            golden_retriever  0.610171    True
# 209         1                       teddy  0.953071   False
# 1646        2                    airedale  0.454239    True
# 1996        1          labrador_retriever  0.836052    True
# 180         1            golden_retriever  0.919584    True
# 637         1             tibetan_terrier  0.382101    True
# 939         2                       boxer  0.838994    True
# 420         1                  toy_poodle  0.927975    True
# 1976        2  greater_swiss_mountain_dog  0.622752    True
#
#                               p2   p2_conf  p2_dog                p3  \
# 1465               irish_terrier  0.121488    True  lakeland_terrier
# 1618          labrador_retriever  0.173252    True    cocker_spaniel
# 209                        koala  0.007027   False          fur_coat
# 1646              cocker_spaniel  0.219323    True     irish_terrier
# 1996   staffordshire_bullterrier  0.047069    True            beagle
# 180           labrador_retriever  0.049669    True            kuvasz
# 637             miniature_poodle  0.095429    True       maltese_dog
# 939   greater_swiss_mountain_dog  0.088800    True      bull_mastiff
# 420             miniature_poodle  0.068946    True   standard_poodle
# 1976                 appenzeller  0.158463    True       entlebucher
#
#        p3_conf  p3_dog
# 1465  0.014603    True
# 1618  0.163257    True
# 209   0.005368   False
# 1646  0.093193    True
# 1996  0.036007    True
# 180   0.010216    True
# 637   0.065738    True
# 939   0.031684    True
# 420   0.001316    True
# 1976  0.148115    True

# %% [markdown]
# ### Clean 2 Tidiness Issues

# %% [markdown]
# **Issue #1:**<br />
#
# **Define** <br />
# Remove the retweeted images because we only want original tweets. We will drop the columns in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, and retweeted_status_timestamp. From the df_json_clean dataset we can drop the "Unnamed: 0" column.

# %% [markdown]
# **Code**

# %%
# Drop the "in-reply", "retweeted", and "Unnamed: 0" columns 
#df_twitter_archive_clean.drop("in_reply_to_status_id" , inplace = True)
#df_twitter_archive_clean.drop(['in_reply_to_user_id'], axis=1, inplace = True)
#df_twitter_archive_clean.drop(['retweeted_status_id'], axis=1, inplace = True)
#df_twitter_archive_clean.drop(['retweeted_status_user_id'], axis=1, inplace = True)
#df_twitter_archive_clean.drop(['retweeted_status_timestamp'], axis=1, inplace = True)
#df_json_clean.drop(['Unnamed: 0'], axis = 1, inplace= True)

# %% [markdown]
# **Test**

# %%
df_twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2336 non-null object
# timestamp             2336 non-null datetime64[ns, UTC]
# source                2336 non-null object
# text                  2336 non-null object
# expanded_urls         2280 non-null object
# rating_numerator      2336 non-null object
# rating_denominator    2336 non-null int64
# name                  2336 non-null object
# doggo                 2336 non-null object
# floofer               2336 non-null object
# pupper                2336 non-null object
# puppo                 2336 non-null object
# dtypes: datetime64[ns, UTC](1), int64(1), object(10)
# memory usage: 317.2+ KB

# %%
df_json_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
# tweet_id          2331 non-null object
# retweet_count     2331 non-null int64
# favorite_count    2331 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 72.8+ KB

# %% [markdown]
# **Issue #2:**<br />
#
# **Define** <br />
# We can combine all three datasets into one dataset called twitter_master_df. First we will combine the df_twitter_archive_clean dataset with image_predictions_clean dataset. Then we will combine that dataset with the df_json_clean dataset to make one master dataset.

# %% [markdown]
# **Code**

# %%
archive_predictions = pd.merge(df_twitter_archive_clean, image_predictions_clean, how='left', on='tweet_id')

# %% [markdown]
# **Test**

# %%
archive_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 0 to 2335
# Data columns (total 23 columns):
# tweet_id              2336 non-null object
# timestamp             2336 non-null datetime64[ns, UTC]
# source                2336 non-null object
# text                  2336 non-null object
# expanded_urls         2280 non-null object
# rating_numerator      2336 non-null object
# rating_denominator    2336 non-null int64
# name                  2336 non-null object
# doggo                 2336 non-null object
# floofer               2336 non-null object
# pupper                2336 non-null object
# puppo                 2336 non-null object
# jpg_url               2059 non-null object
# img_num               2059 non-null float64
# p1                    2059 non-null object
# p1_conf               2059 non-null float64
# p1_dog                2059 non-null object
# p2                    2059 non-null object
# p2_conf               2059 non-null float64
# p2_dog                2059 non-null object
# p3                    2059 non-null object
# p3_conf               2059 non-null float64
# p3_dog                2059 non-null object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1), object(17)
# memory usage: 438.0+ KB

# %% [markdown]
# **Define**<br />
# Combine the archive_predictions dataset with the df_json_clean dataset to make a master dataset.

# %% [markdown]
# **Code**

# %%
df_twitter_master = pd.merge(archive_predictions, df_json_clean, how='left', on='tweet_id')

# %% [markdown]
# **Test**

# %%
df_twitter_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 0 to 2335
# Data columns (total 25 columns):
# tweet_id              2336 non-null object
# timestamp             2336 non-null datetime64[ns, UTC]
# source                2336 non-null object
# text                  2336 non-null object
# expanded_urls         2280 non-null object
# rating_numerator      2336 non-null object
# rating_denominator    2336 non-null int64
# name                  2336 non-null object
# doggo                 2336 non-null object
# floofer               2336 non-null object
# pupper                2336 non-null object
# puppo                 2336 non-null object
# jpg_url               2059 non-null object
# img_num               2059 non-null float64
# p1                    2059 non-null object
# p1_conf               2059 non-null float64
# p1_dog                2059 non-null object
# p2                    2059 non-null object
# p2_conf               2059 non-null float64
# p2_dog                2059 non-null object
# p3                    2059 non-null object
# p3_conf               2059 non-null float64
# p3_dog                2059 non-null object
# retweet_count         2311 non-null float64
# favorite_count        2311 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1), object(17)
# memory usage: 474.5+ KB

# %% [markdown]
# **Define**<br />
# Drop any rows that do not contain a jpg_url. This will enable easier analyses later on.

# %% [markdown]
# **Code**

# %%
df_twitter_master = df_twitter_master[df_twitter_master['jpg_url'].notnull()]

# %% [markdown]
# **Test**

# %%
df_twitter_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2059 entries, 0 to 2335
# Data columns (total 25 columns):
# tweet_id              2059 non-null object
# timestamp             2059 non-null datetime64[ns, UTC]
# source                2059 non-null object
# text                  2059 non-null object
# expanded_urls         2059 non-null object
# rating_numerator      2059 non-null object
# rating_denominator    2059 non-null int64
# name                  2059 non-null object
# doggo                 2059 non-null object
# floofer               2059 non-null object
# pupper                2059 non-null object
# puppo                 2059 non-null object
# jpg_url               2059 non-null object
# img_num               2059 non-null float64
# p1                    2059 non-null object
# p1_conf               2059 non-null float64
# p1_dog                2059 non-null object
# p2                    2059 non-null object
# p2_conf               2059 non-null float64
# p2_dog                2059 non-null object
# p3                    2059 non-null object
# p3_conf               2059 non-null float64
# p3_dog                2059 non-null object
# retweet_count         2043 non-null float64
# favorite_count        2043 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1), object(17)
# memory usage: 418.2+ KB

# %% [markdown]
# **Define**<br />
# Set the following columns to the correct data type:<br />
# p1_dog, p2_dog, p3_dog --> bool<br />
# rating_numerator --> float<br />

# %% [markdown]
# **Code**

# %%
df_twitter_master['p1_dog'] = df_twitter_master['p1_dog'].astype(bool)
df_twitter_master['p2_dog'] = df_twitter_master['p2_dog'].astype(bool)
df_twitter_master['p3_dog'] = df_twitter_master['p3_dog'].astype(bool)
df_twitter_master['rating_numerator'] = df_twitter_master['rating_numerator'].astype(float)

# %% [markdown]
# **Test**

# %%
df_twitter_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2059 entries, 0 to 2335
# Data columns (total 25 columns):
# tweet_id              2059 non-null object
# timestamp             2059 non-null datetime64[ns, UTC]
# source                2059 non-null object
# text                  2059 non-null object
# expanded_urls         2059 non-null object
# rating_numerator      2059 non-null float64
# rating_denominator    2059 non-null int64
# name                  2059 non-null object
# doggo                 2059 non-null object
# floofer               2059 non-null object
# pupper                2059 non-null object
# puppo                 2059 non-null object
# jpg_url               2059 non-null object
# img_num               2059 non-null float64
# p1                    2059 non-null object
# p1_conf               2059 non-null float64
# p1_dog                2059 non-null bool
# p2                    2059 non-null object
# p2_conf               2059 non-null float64
# p2_dog                2059 non-null bool
# p3                    2059 non-null object
# p3_conf               2059 non-null float64
# p3_dog                2059 non-null bool
# retweet_count         2043 non-null float64
# favorite_count        2043 non-null float64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(7), int64(1), object(13)
# memory usage: 376.0+ KB

# %% [markdown]
# **Issue #3(for fun):**<br />
#
# **Define** <br />
# The columns doggo, floofer, pupper, and puppo can be condensed into one column called Stage with the possible variables as doggo, floofer, pupper, and puppo.

# %% [markdown]
# **Code**

# %%
# First, we will substitute all the NaN for null values. 
df_twitter_master['doggo'].replace(np.nan,'', inplace=True)
df_twitter_master['floofer'].replace(np.nan,'', inplace=True)
df_twitter_master['pupper'].replace(np.nan,'', inplace=True)
df_twitter_master['puppo'].replace(np.nan, '', inplace=True)

# %%
df_twitter_master['stage'] = 'None'

def get_dog_stage(row):
    stage = []
    if row['doggo'] == 'doggo':
        stage.append('doggo')
    if row['floofer'] == 'floofer':
        stage.append('floofer')
    if row['pupper'] == 'pupper':
        stage.append('pupper')
    if row['puppo'] == 'puppo':
        stage.append('puppo')
    
    if len(stage) < 1:
        row['stage'] = 'None'
    else:
        row['stage'] = ','.join(stage)
        
    return row

df_twitter_master = df_twitter_master.apply(get_dog_stage, axis=1)

# %%
df_twitter_master.stage.value_counts()
# Out:
# None             1738
# pupper            211
# doggo              67
# puppo              23
# doggo,pupper       11
# floofer             7
# doggo,puppo         1
# doggo,floofer       1
# Name: stage, dtype: int64

# %%
df_twitter_master['stage'].replace('doggo,pupper','doggo-pupper', inplace=True)
df_twitter_master['stage'].replace('doggo,floofer','doggo-floofer', inplace=True)
df_twitter_master['stage'].replace('doggo,puppo','doggo-puppo', inplace=True)

# %%
df_twitter_master.stage.value_counts()
# Out:
# None             1738
# pupper            211
# doggo              67
# puppo              23
# doggo-pupper       11
# floofer             7
# doggo-puppo         1
# doggo-floofer       1
# Name: stage, dtype: int64

# %%
df_twitter_master = df_twitter_master.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis = 1)

# %%
df_twitter_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2059 entries, 0 to 2335
# Data columns (total 22 columns):
# tweet_id              2059 non-null object
# timestamp             2059 non-null datetime64[ns, UTC]
# source                2059 non-null object
# text                  2059 non-null object
# expanded_urls         2059 non-null object
# rating_numerator      2059 non-null float64
# rating_denominator    2059 non-null int64
# name                  2059 non-null object
# jpg_url               2059 non-null object
# img_num               2059 non-null float64
# p1                    2059 non-null object
# p1_conf               2059 non-null float64
# p1_dog                2059 non-null bool
# p2                    2059 non-null object
# p2_conf               2059 non-null float64
# p2_dog                2059 non-null bool
# p3                    2059 non-null object
# p3_conf               2059 non-null float64
# p3_dog                2059 non-null bool
# retweet_count         2043 non-null float64
# favorite_count        2043 non-null float64
# stage                 2059 non-null object
# dtypes: bool(3), datetime64[ns, UTC](1), float64(7), int64(1), object(10)
# memory usage: 327.8+ KB

# %% [markdown]
# ## Storing and Acting on Wrangled Data ##

# %% [markdown]
# ### Store Data ##

# %%
# Store the clean dataframe in a CSV file with the main one named twitter_archive_master.csv. 
df_twitter_master.to_csv('twitter_archive_master.csv')

# %% [markdown]
# ### Act on Data ###
# ### Insight #1: Top rated and lowest rated dogs <br />
# Because these ratings are subjective, I will show the top 3 rated dogs and the 3 lowest rated dogs.

# %%
# Sort the master dataframe by rating_numerator values so that we can see the top 3 highest and lowest rated dogs
pd.set_option('display.max_colwidth', 150)
df_twitter_master.sort_values(by = 'rating_numerator').head(20)
# Out:
#                 tweet_id                 timestamp  \
# 1068  740214038584557568 2016-06-07 16:09:13+00:00
# 1074  739544079319588864 2016-06-05 19:47:03+00:00
# 1007  747512671126323200 2016-06-27 19:31:23+00:00
# 803   772114945936949249 2016-09-03 16:52:02+00:00
# 986   748977405889503236 2016-07-01 20:31:43+00:00
# 1108  733482008106668032 2016-05-20 02:18:32+00:00
# 1081  738402415918125056 2016-06-02 16:10:29+00:00
# 888   759566828574212096 2016-07-31 01:50:18+00:00
# 1095  736010884653420544 2016-05-27 01:47:23+00:00
# 1623  684594889858887680 2016-01-06 04:38:35+00:00
# 1319  706291001778950144 2016-03-06 01:31:11+00:00
# 1014  746872823977771008 2016-06-26 01:08:52+00:00
# 1006  747594051852075008 2016-06-28 00:54:46+00:00
# 1013  747103485104099331 2016-06-26 16:25:26+00:00
# 1338  704847917308362754 2016-03-02 01:56:53+00:00
# 1263  709852847387627521 2016-03-15 21:24:41+00:00
# 1432  697259378236399616 2016-02-10 03:22:44+00:00
# 1022  746369468511756288 2016-06-24 15:48:42+00:00
# 1606  685532292383666176 2016-01-08 18:43:29+00:00
# 1369  702217446468493312 2016-02-23 19:44:20+00:00
#
#                                                                                   source  \
# 1068  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1074  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1007  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 803   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 986   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1108  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1081  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 888   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1095  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1623  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1319  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1014  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1006  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1013  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1338  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1263  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1432  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1022  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1606  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1369  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                               text  \
# 1068   This is getting incredibly frustrating. This is a Mexican Golden Beaver. We only rate dogs. Only send dogs ...10/10 https://t.co/0yolOOyD3X
# 1074                       This... is a Tyrannosaurus rex. We only rate dogs. Please only send in dogs. Thank you ...10/10 https://t.co/zxw8d5g94P
# 1007   Guys pls stop sending actual sharks. It's too dangerous for me and the people taking the photos. Thank you ...10/10 https://t.co/12lICZN2SP
# 803           This is Finn. He's very nervous for the game. Has a lot of money riding on it.10/10 would attempt to comfort https://t.co/CbtNfecWiT
# 986       What jokester sent in a pic without a dog in it? This is not @rock_rates. This is @dog_rates. Thank you ...10/10 https://t.co/nDPaYHrtNX
# 1108                                                                          "Ello this is dog how may I assist" ...10/10 https://t.co/jeAENpjH7L
# 1081                                                             "Don't talk to me or my son ever again" ...10/10 for both https://t.co/s96OYXZIfK
# 888         RT @dog_rates: This... is a Tyrannosaurus rex. We only rate dogs. Please only send in dogs. Thank you ...10/10 https://t.co/zxw8d5g94P
# 1095   Right after you graduate vs when you remember you're on your own now and can barely work a washing machine ...10/10 https://t.co/O1TLuYjsNS
# 1623                          "FOR THE LAST TIME I DON'T WANNA PLAY TWISTER ALL THE SPOTS ARE GREY DAMN IT CINDY" ...10/10 https://t.co/uhQNehTpIu
# 1319            When you're just relaxin and having a swell time but then remember you have to fill out the FAFSA ...11/10 https://t.co/qy33OBcexg
# 1014        This is a carrot. We only rate dogs. Please only send in dogs. You all really should know this by now ...11/10 https://t.co/9e48aPrBm2
# 1006  Again w the sharks guys. This week is about dogs ACTING or DRESSING like sharks. NOT actual sharks. Thank u ...11/10 https://t.co/Ie2mWXWjpr
# 1013     Guys... I said DOGS with "shark qualities" or "costumes." Not actual sharks. This did me a real frighten ...11/10 https://t.co/DX1JUHJVN7
# 1338                                                              "Yes hi could I get a number 4 with no pickles" ...12/10 https://t.co/kQPVxqA3gq
# 1263                                                                 *lets out a tiny whimper and then collapses* ...12/10 https://t.co/BNdVZEHRow
# 1432                  Please stop sending in saber-toothed tigers. This is getting ridiculous. We only rate dogs.\n...8/10 https://t.co/iAeQNueou8
# 1022    This is an Iraqi Speed Kangaroo. It is not a dog. Please only send in dogs. I'm very angry with all of you ...9/10 https://t.co/5qpBTTpgUt
# 1606          For the last time, WE. DO. NOT. RATE. BULBASAUR. We only rate dogs. Please only send dogs. Thank you ...9/10 https://t.co/GboDG8WhJG
# 1369                              I know it's tempting, but please stop sending in pics of Donald Trump. Thank you ...9/10 https://t.co/y35Y1TJERY
#
#                                                                                                                                               expanded_urls  \
# 1068                                                                                        https://twitter.com/dog_rates/status/740214038584557568/photo/1
# 1074                                                                                        https://twitter.com/dog_rates/status/739544079319588864/photo/1
# 1007                                                                                        https://twitter.com/dog_rates/status/747512671126323200/photo/1
# 803                                                                                         https://twitter.com/dog_rates/status/772114945936949249/photo/1
# 986                                                                                         https://twitter.com/dog_rates/status/748977405889503236/photo/1
# 1108                                                                                        https://twitter.com/dog_rates/status/733482008106668032/photo/1
# 1081                                                                                        https://twitter.com/dog_rates/status/738402415918125056/photo/1
# 888                         https://twitter.com/dog_rates/status/739544079319588864/photo/1,https://twitter.com/dog_rates/status/739544079319588864/photo/1
# 1095                        https://twitter.com/dog_rates/status/736010884653420544/photo/1,https://twitter.com/dog_rates/status/736010884653420544/photo/1
# 1623                                                                                        https://twitter.com/dog_rates/status/684594889858887680/photo/1
# 1319                        https://twitter.com/dog_rates/status/706291001778950144/photo/1,https://twitter.com/dog_rates/status/706291001778950144/photo/1
# 1014                        https://twitter.com/dog_rates/status/746872823977771008/photo/1,https://twitter.com/dog_rates/status/746872823977771008/photo/1
# 1006                                                                                        https://twitter.com/dog_rates/status/747594051852075008/photo/1
# 1013  https://twitter.com/dog_rates/status/747103485104099331/photo/1,https://twitter.com/dog_rates/status/747103485104099331/photo/1,https://twitter.co...
# 1338                                                                                        https://twitter.com/dog_rates/status/704847917308362754/photo/1
# 1263  https://twitter.com/dog_rates/status/709852847387627521/photo/1,https://twitter.com/dog_rates/status/709852847387627521/photo/1,https://twitter.co...
# 1432                                                                                        https://twitter.com/dog_rates/status/697259378236399616/photo/1
# 1022                                                                                        https://twitter.com/dog_rates/status/746369468511756288/photo/1
# 1606                                                                                        https://twitter.com/dog_rates/status/685532292383666176/photo/1
# 1369                                                                                        https://twitter.com/dog_rates/status/702217446468493312/photo/1
#
#       rating_numerator  rating_denominator     name  \
# 1068              0.10                  10  getting
# 1074              0.10                  10      NaN
# 1007              0.10                  10      NaN
# 803               0.10                  10     Finn
# 986               0.10                  10      not
# 1108              0.10                  10      NaN
# 1081              0.10                  10      NaN
# 888               0.10                  10      NaN
# 1095              0.10                  10      NaN
# 1623              0.10                  10      NaN
# 1319              0.11                  10      NaN
# 1014              0.11                  10      NaN
# 1006              0.11                  10      NaN
# 1013              0.11                  10      NaN
# 1338              0.12                  10      NaN
# 1263              0.12                  10      NaN
# 1432              0.80                  10  getting
# 1022              0.90                  10      NaN
# 1606              0.90                  10      NaN
# 1369              0.90                  10      NaN
#
#                                               jpg_url  img_num  ... p1_dog  \
# 1068  https://pbs.twimg.com/media/CkXEu2OUoAAs8yU.jpg      1.0  ...   True
# 1074  https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg      1.0  ...   True
# 1007  https://pbs.twimg.com/media/Cl-yykwWkAAqUCE.jpg      1.0  ...   True
# 803   https://pbs.twimg.com/media/Crcacf9WgAEcrMh.jpg      1.0  ...   True
# 986   https://pbs.twimg.com/media/CmTm-XQXEAAEyN6.jpg      1.0  ...   True
# 1108  https://pbs.twimg.com/media/Ci3Z_idUkAA8RUh.jpg      1.0  ...   True
# 1081  https://pbs.twimg.com/media/Cj9VEs_XAAAlTai.jpg      1.0  ...   True
# 888   https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg      1.0  ...   True
# 1095  https://pbs.twimg.com/media/CjbV-lEWgAAr6WY.jpg      2.0  ...   True
# 1623  https://pbs.twimg.com/media/CYAra7JWsAACPZH.jpg      1.0  ...   True
# 1319  https://pbs.twimg.com/media/Cc0_2tXXEAA2iTY.jpg      1.0  ...   True
# 1014  https://pbs.twimg.com/media/Cl1s1p7WMAA44Vk.jpg      1.0  ...   True
# 1006  https://pbs.twimg.com/media/Cl_80k5WkAEbo9m.jpg      1.0  ...   True
# 1013  https://pbs.twimg.com/media/Cl4-pevXEAAb8VW.jpg      1.0  ...   True
# 1338  https://pbs.twimg.com/media/CcgfcANW4AA9hzr.jpg      1.0  ...   True
# 1263  https://pbs.twimg.com/media/CdnnZhhWAAEAoUc.jpg      2.0  ...   True
# 1432  https://pbs.twimg.com/media/Ca0ps3AXEAAnp9m.jpg      1.0  ...   True
# 1022  https://pbs.twimg.com/media/ClujESVXEAA4uH8.jpg      1.0  ...   True
# 1606  https://pbs.twimg.com/media/CYN_-6iW8AQhPu2.jpg      1.0  ...  False
# 1369  https://pbs.twimg.com/media/Cb7HCMkWEAAV9zY.jpg      1.0  ...   True
#
#                       p2   p2_conf p2_dog                           p3  \
# 1068  labrador_retriever  0.189782   True                       vizsla
# 1074    golden_retriever  0.016641   True                     ice_bear
# 1007            malinois  0.095089   True              german_shepherd
# 803          toy_terrier  0.052980   True            italian_greyhound
# 986             bluetick  0.152810   True               english_setter
# 1108   computer_keyboard  0.142274  False                        mouse
# 1081    blenheim_spaniel  0.193905   True                    chihuahua
# 888     golden_retriever  0.016641   True                     ice_bear
# 1095  labrador_retriever  0.119475   True                     bluetick
# 1623      english_setter  0.035352   True             brittany_spaniel
# 1319        bull_mastiff  0.164087   True    staffordshire_bullterrier
# 1014              beagle  0.207835   True            italian_greyhound
# 1006               dingo  0.270226  False                    chihuahua
# 1013    golden_retriever  0.002228   True                      doormat
# 1338  labrador_retriever  0.135460   True              tibetan_mastiff
# 1263          pomeranian  0.019204   True  west_highland_white_terrier
# 1432               boxer  0.000187   True                      whippet
# 1022            malinois  0.338884   True                      wallaby
# 1606               dingo  0.215436  False                       collie
# 1369                chow  0.226800   True               cocker_spaniel
#
#        p3_conf p3_dog  retweet_count  favorite_count  stage
# 1068  0.067607   True         1963.0          6685.0   None
# 1074  0.014858  False        21230.0         39512.0   None
# 1007  0.080146   True         1614.0          5566.0   None
# 803   0.037239   True          474.0          2760.0   None
# 986   0.051835   True         3405.0         10816.0   None
# 1108  0.058505  False          951.0          3131.0   None
# 1081  0.078000   True          838.0          3244.0   None
# 888   0.014858  False            NaN             NaN   None
# 1095  0.077475   True         2982.0          7875.0   None
# 1623  0.003879   True         3501.0          8907.0   None
# 1319  0.105011   True          475.0          1692.0   None
# 1014  0.043565   True         2136.0          5996.0   None
# 1006  0.098939   True         1058.0          3694.0   None
# 1013  0.001404  False         3967.0          9583.0   None
# 1338  0.001903   True         1522.0          5067.0   None
# 1263  0.010134   True         1198.0          3514.0   None
# 1432  0.000151   True         1002.0          3290.0   None
# 1022  0.024161  False         1633.0          6188.0   None
# 1606  0.095805   True         1154.0          3029.0   None
# 1369  0.194086   True         1331.0          4771.0   None
#
# [20 rows x 22 columns]

# %% [markdown]
# **Observations**<br />
#
# First highest rated dog<br />
# Tweet: This is Atticus. He's quite simply America af. 1776/10

# %% [markdown]
# Second highest rated dog<br />
# Tweet: After so many requests... here you go.\n\nGood dogg. 420/10

# %% [markdown]
# The three most popular dog names are Oliver, Cooper, Charlie, and Lucy for a tie at 10 each

# %% [markdown]
# ### Insight #3: Tweet source types ###

# %%
# count the unique values of source types
df_twitter_master.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2019
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       29
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
print(2019+29+11)
# Out:
# 2059

# %%
print(2019/2059)
print(29/2059)
print(11/2059)
# Out:
# 0.9805730937348227
# 0.014084507042253521
# 0.005342399222923749

# %% [markdown]
# **Observations:**<br />
# 98% of users are using an iPhone to view tweets, 1.4% are using a desktop, and 0.5% are using Tweetdeck.

# %% [markdown]
# ## Report (and Visualizations) ##

# %% [markdown]
# ### Visualization #1: Correlation between retweet and favorite count

# %%
# Make a new dataframe with only the columns we need
df_1 = df_twitter_master[['retweet_count', 'favorite_count']]

# We will use seaborn to make a scatterplot with a regression line
sns.regplot(df_1['retweet_count'], df_1['favorite_count']).set_title(
    "Correlation Between Retweet and Favorite Count", size = 15)

# Save the plot so that we can use it for the separate reports
plt.savefig('Correlation Between Retweet and Favorite Count.jpg')

# %% [markdown]
# **Observations:**<br />
# I chose this visualization because I noticed that while assessing for 3 insights, the most favorited and most retweeted tweet are the same. It got me thinking what is the correlation betweetn retweet_count and favorite_count variables? By looking at the graph above and doing a visual assessment, we can infer that a greater number of retweets will increase the likelihood that the tweet will also be favorited. There is a steep, positive correlation based on the best fit line of the graph. Every increase in retweet count will get multiple favorite hits.

# %% [markdown]
# ### Visualization #2: Algorithms' Success Rate###<br />
# We will condense the 3 algorithms with 6 columns into 2 columns by melting it. We will then be able to use this new dataframe to create a boxplot graph. This graph will show how successful each of the alogrithims are compared to one another.

# %%
# Start off by gathering the columns from the master dataframe that we only need.
df_2 = df_twitter_master[['p1_conf', 'p1_dog', 'p2_conf', 'p2_dog', 'p3_conf', 'p3_dog']]
df_2.rename(columns={'p1_dog':'p1_bool',
                          'p2_dog':'p2_bool',
                          'p3_dog':'p3_bool'}, 
                 inplace=True)
# Test it out
df_2.head()
# Out:
# C:\Users\khana\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#     p1_conf  p1_bool   p2_conf  p2_bool   p3_conf  p3_bool
# 0  0.097049    False  0.085851    False  0.076110    False
# 1  0.323581     True  0.090647     True  0.068957     True
# 2  0.716012     True  0.078253     True  0.031379     True
# 3  0.170278    False  0.168086     True  0.040836    False
# 4  0.555712     True  0.225770     True  0.175219     True

# %%
# We want to melt each of the columns into 2 columns.
p1_df = pd.melt(df_2, value_vars=['p1_conf'],
          var_name='algorithm', value_name='confidence_interval')
p1_df['bool'] = df_2['p1_bool']

# Test it out
p1_df.head()
# Out:
#   algorithm  confidence_interval   bool
# 0   p1_conf             0.097049  False
# 1   p1_conf             0.323581   True
# 2   p1_conf             0.716012   True
# 3   p1_conf             0.170278  False
# 4   p1_conf             0.555712   True

# %%
# Do the same with the other remaining columns
p2_df = pd.melt(df_2, value_vars=['p2_conf'],
               var_name='algorithm', value_name= 'confidence_interval')
p2_df['bool'] = df_2['p2_bool']

# Test it out
p2_df.head()
# Out:
#   algorithm  confidence_interval   bool
# 0   p2_conf             0.085851  False
# 1   p2_conf             0.090647   True
# 2   p2_conf             0.078253   True
# 3   p2_conf             0.168086   True
# 4   p2_conf             0.225770   True

# %%
# Do the same with the other remaining columns
p3_df = pd.melt(df_2, value_vars=['p3_conf'],
               var_name='algorithm', value_name= 'confidence_interval')
p3_df['bool'] = df_2['p3_bool']

# Test it out
p3_df.head()
# Out:
#   algorithm  confidence_interval   bool
# 0   p3_conf             0.076110  False
# 1   p3_conf             0.068957   True
# 2   p3_conf             0.031379   True
# 3   p3_conf             0.040836  False
# 4   p3_conf             0.175219   True

# %%
# Create a new dataframe from the melted dataframes. 
df_2_new = pd.concat([p1_df, p2_df, p3_df], ignore_index= True)

# Test it out
df_2_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6177 entries, 0 to 6176
# Data columns (total 3 columns):
# algorithm              6177 non-null object
# confidence_interval    6177 non-null float64
# bool                   5358 non-null object
# dtypes: float64(1), object(2)
# memory usage: 144.9+ KB

# %%
# Drop the "_conf" in each of the rows because we do not need it anymore
df_2_new['algorithm'].replace('_conf','', regex=True, inplace=True)

# Test it out
df_2_new
# Out:
#      algorithm  confidence_interval   bool
# 0           p1             0.097049  False
# 1           p1             0.323581   True
# 2           p1             0.716012   True
# 3           p1             0.170278  False
# 4           p1             0.555712   True
# ...        ...                  ...    ...
# 6172        p3             0.154629   True
# 6173        p3             0.222752   True
# 6174        p3             0.116197   True
# 6175        p3             0.072010   True
# 6176        p3             0.061428   True
#
# [6177 rows x 3 columns]

# %%
# Set the style of the boxplot to whitegrid
sns.set(style="whitegrid")

# Set boxplot parameters and properties to my liking
sns.boxplot(x="algorithm", y="confidence_interval", hue="bool", data=df_2_new, palette="bright").set_title(
    'Success Rates of Algorithms', size= 15)
plt.figure(figsize=(5, 8))

# Save the figure for the separate reports
plt.savefig('Success Rates of Algorithms.jpg')

# %% [markdown]
# **Observations:**<br />
# Based on confidence intervals, p1 had highest percentage of confidence but there is a less amount of predictions that came out to be true. With p2, there is less confidence percentage (10-20%) but more predictions that came true. Lastly, p3 had the lowest confidence percentage(5-10%) and had about the same amount of true and false outcomes. The results show that there is approximately an equal amount of True and False outcomes for each of the algorithms, suggesting that each of the algorithms have a success rate of the same.
